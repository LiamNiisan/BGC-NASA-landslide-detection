# %% [markdown]
# # Location Positive/Negative Sentence Classification
# - Building a logistic regression model to detect whether a sentence contains the gold location description keywords
# - Train and predict on the processed NASA example (through Badr's model) `new_filter_train_set.csv`

# %%
import pandas as pd
import re
import numpy as np
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import RandomizedSearchCV, cross_validate
from sklearn.dummy import DummyClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score,
    make_scorer,
    precision_score,
    recall_score,
)
from collections import defaultdict
import geocoder
import numpy as np
import geopy.distance
from scipy.spatial.distance import euclidean

# %% [markdown]
# ## 1. Data Preprocessing

# %%
nasa = pd.read_csv("../data/nasa_global_landslide_catalog_point.csv")
nasa = nasa.reset_index()
nasa = nasa.rename(columns={"index": "id"})  # id: index in NASA dataset

label = pd.read_csv('../data/new_filter_train_set.csv', index_col=0)

df = pd.merge(label, nasa, how='left', on='id')

# %%
new_df = df[['id', 'text', 'location_description', 'GPE', 'LOC', 'DATE', 'TIME']]
new_df = new_df.fillna('')  # replace NAN with empty string
new_df['locations'] = new_df[['GPE', 'LOC']].agg('|'.join, axis=1)  # join GPE and LOC by |
new_df['dates'] = new_df[['DATE','TIME']].agg('|'.join, axis=1)  # join DATE and TIME by |
new_df = new_df.drop(columns=['GPE', 'LOC', 'DATE', 'TIME'])  # keep only the joined column
new_df
# Out:
#           id                                               text  \
# 0          0  Reported By: | Edited By: |Source: ANI |Update...
# 1          0  At least 12 people are feared to be buried und...
# 2          0  The landslide is said to have taken place at 3...
# 3          0  Ratnagiri (Maharashtra): Landslide occurred at...
# 4          0           pic.twitter.com/MOcmTxnAZX June 22, 2015
# ...      ...                                                ...
# 26128  35646  Meanwhile, the Kanchanjunga Academy Higher Sec...
# 26129  35649  Follow us on landslide blocks doda batote high...
# 26130  35649  The highway was blocked after a landslide hit ...
# 26131  35649  He said that the work to open the highway was ...
# 26132  35649  “If there is no rain, we might throw the road ...
#
#                                     location_description  \
# 0      Dabhol village of Maharashtra's Ratnagiri dist...
# 1      Dabhol village of Maharashtra's Ratnagiri dist...
# 2      Dabhol village of Maharashtra's Ratnagiri dist...
# 3      Dabhol village of Maharashtra's Ratnagiri dist...
# 4      Dabhol village of Maharashtra's Ratnagiri dist...
# ...                                                  ...
# 26128  Phidim-Raanke section of the Mechi Highway at ...
# 26129           Chakwa bridge, 9 kilomters short of Doda
# 26130           Chakwa bridge, 9 kilomters short of Doda
# 26131           Chakwa bridge, 9 kilomters short of Doda
# 26132           Chakwa bridge, 9 kilomters short of Doda
#
#                            locations                       dates
# 0                                  |  Aug 04 , 2015|11:39 AM IST
# 1      Dabhol|Maharashtra|Ratnagiri|                           |
# 2                                  |                    |3:30 am
# 3             Ratnagiri|Maharashtra|            |3 : 30 am today
# 4                                  |             June 22 , 2015|
# ...                              ...                         ...
# 26128                      Phidim-1|                           |
# 26129                         Jammu|                           |
# 26130                          Doda|               |last evening
# 26131                              |               today|evening
# 26132                              |               today|evening
#
# [26133 rows x 5 columns]

# %%
print(f"total number of documnets: {np.count_nonzero(new_df['id'].unique())}")
# Out:
# total number of documnets: 3208

# %% [markdown]
# - Get the POS/NEG label for each sentence
#     - First do exact match: if `location_description` appears in `text`, mark the sentence as a positive sentence (`pos_setence=Yes`), otherwise, mark the sentence as a negative sentence (`pos_setence=No`).
#     - Then do partial match: if one or more location entities in the sentence appear in the gold label (`location_description`), mark the sentence as a positive sentence (`pos_setence=Yes`), otherwise, mark the sentence as a negative sentence (`pos_setence=No`).

# %%
data = new_df.to_dict()  # transform dataframe into dictionary

data['pos_sentence'] = {}
n = defaultdict(int)
data['number_of_pos_sent'] = {}
data['contain_pos_sent'] = {}

# exact match
# iterate over each sentence in the data
for i in range(len(data['text'])):
    if data['location_description'][i] in data['text'][i]:
        data['pos_sentence'][i] = 'Yes'
        n[data['id'][i]] += 1
    else:
        data['pos_sentence'][i] = 'No'
        
# partial match
for i in range(len(data['text'])):
    if n[data['id'][i]] == 0:
        locs = list(filter(None, data['locations'][i].split("|"))) 
        if any(loc in data['location_description'][i] for loc in locs):
            data['pos_sentence'][i] = 'Yes'
            n[data['id'][i]] += 1
        else:
            data['pos_sentence'][i] = 'No'

# count how many pos_sentence each document has
# count how many documents contain gold place name, how many doesn't
for i in range(len(data['text'])):
    if n[data['id'][i]] == 0:
        data['number_of_pos_sent'][i] = 0
        data['contain_pos_sent'][i] = False
    else:
        data['number_of_pos_sent'][i] = n[data['id'][i]]
        data['contain_pos_sent'][i] = True

# %%
data_df = pd.DataFrame(data)
data_df
# Out:
#           id                                               text  \
# 0          0  Reported By: | Edited By: |Source: ANI |Update...
# 1          0  At least 12 people are feared to be buried und...
# 2          0  The landslide is said to have taken place at 3...
# 3          0  Ratnagiri (Maharashtra): Landslide occurred at...
# 4          0           pic.twitter.com/MOcmTxnAZX June 22, 2015
# ...      ...                                                ...
# 26128  35646  Meanwhile, the Kanchanjunga Academy Higher Sec...
# 26129  35649  Follow us on landslide blocks doda batote high...
# 26130  35649  The highway was blocked after a landslide hit ...
# 26131  35649  He said that the work to open the highway was ...
# 26132  35649  “If there is no rain, we might throw the road ...
#
#                                     location_description  \
# 0      Dabhol village of Maharashtra's Ratnagiri dist...
# 1      Dabhol village of Maharashtra's Ratnagiri dist...
# 2      Dabhol village of Maharashtra's Ratnagiri dist...
# 3      Dabhol village of Maharashtra's Ratnagiri dist...
# 4      Dabhol village of Maharashtra's Ratnagiri dist...
# ...                                                  ...
# 26128  Phidim-Raanke section of the Mechi Highway at ...
# 26129           Chakwa bridge, 9 kilomters short of Doda
# 26130           Chakwa bridge, 9 kilomters short of Doda
# 26131           Chakwa bridge, 9 kilomters short of Doda
# 26132           Chakwa bridge, 9 kilomters short of Doda
#
#                            locations                       dates pos_sentence  \
# 0                                  |  Aug 04 , 2015|11:39 AM IST           No
# 1      Dabhol|Maharashtra|Ratnagiri|                           |          Yes
# 2                                  |                    |3:30 am           No
# 3             Ratnagiri|Maharashtra|            |3 : 30 am today           No
# 4                                  |             June 22 , 2015|           No
# ...                              ...                         ...          ...
# 26128                      Phidim-1|                           |           No
# 26129                         Jammu|                           |           No
# 26130                          Doda|               |last evening          Yes
# 26131                              |               today|evening           No
# 26132                              |               today|evening           No
#
#        number_of_pos_sent  contain_pos_sent
# 0                       1              True
# 1                       1              True
# 2                       1              True
# 3                       1              True
# 4                       1              True
# ...                   ...               ...
# 26128                   1              True
# 26129                   1              True
# 26130                   1              True
# 26131                   1              True
# 26132                   1              True
#
# [26133 rows x 8 columns]

# %%
describe_df = data_df[['id', 'number_of_pos_sent', 'contain_pos_sent']].drop_duplicates()
print(f"Distribution of number of positive sentence each document has: \n{describe_df['number_of_pos_sent'].value_counts().sort_index()}\n")
print(f"How many documents contain gold place name: \n{describe_df['contain_pos_sent'].value_counts()}")
# Out:
# Distribution of number of positive sentence each document has:
# 0      567
# 1     2498
# 2       74
# 3       29
# 4       11
# 5        6
# 6        6
# 7        2
# 8        1
# 9        4
# 10       3
# 11       1
# 12       1
# 13       4
# 18       1
# 19       1
# Name: number_of_pos_sent, dtype: int64
#
# How many documents contain gold place name:
# True     2642
# False     567
# Name: contain_pos_sent, dtype: int64

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26133 entries, 0 to 26132
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    26133 non-null  int64
#  1   text                  26133 non-null  object
#  2   location_description  26133 non-null  object
#  3   locations             26133 non-null  object
#  4   dates                 26133 non-null  object
#  5   pos_sentence          26133 non-null  object
#  6   number_of_pos_sent    26133 non-null  int64
#  7   contain_pos_sent      26133 non-null  bool
# dtypes: bool(1), int64(2), object(5)
# memory usage: 1.6+ MB

# %%
data_df.shape
# Out:
# (26133, 8)

# %%
data_df['pos_sentence'].value_counts()
# Out:
# No     23090
# Yes     3043
# Name: pos_sentence, dtype: int64

# %%
data = data_df[data_df['contain_pos_sent']]  # delete documents that doesn't have gold location_description in the text

# %% [markdown]
# ## 2. Prepration for Model

# %%
df_train, df_test = train_test_split(data, test_size=0.20, shuffle=False, random_state=123)

X_train, y_train = df_train["text"], df_train["pos_sentence"]  # change text into masked_text and try again
X_test, y_test = df_test["text"], df_test["pos_sentence"]

# %% [markdown]
# ## 3. Train the best model

# %%
best_model = make_pipeline(TfidfVectorizer(ngram_range=(1,2)), LogisticRegression(max_iter=2000, class_weight='balanced'))
best_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidfvectorizer', TfidfVectorizer(ngram_range=(1, 2))),
#                 ('logisticregression',
#                  LogisticRegression(class_weight='balanced', max_iter=2000))])

# %%
print(classification_report(y_test, best_model.predict(X_test)))  # precision for yes is important
# Out:
#               precision    recall  f1-score   support
#
#           No       0.92      0.82      0.87      3826
#          Yes       0.35      0.60      0.44       645
#
#     accuracy                           0.78      4471
#    macro avg       0.64      0.71      0.66      4471
# weighted avg       0.84      0.78      0.81      4471

# %% [markdown]
# ## 4. Generate prediction results
# ### 4.1 Example preparation
# - Use the test set to evaluate the prediction results

# %%
best_model.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
best_model.predict_proba(X_test[:20])[:,1]  # probability of being a positive sentence
# Out:
# array([0.17006319, 0.36382099, 0.60410395, 0.70408078, 0.42688206,
#        0.31807105, 0.25624586, 0.87002064, 0.58640418, 0.17677036,
#        0.21567752, 0.84952536, 0.25241687, 0.52955796, 0.44922223,
#        0.71060289, 0.29952627, 0.2381091 , 0.87641206, 0.61065415])

# %%
example = df_test  # data_df[:996]
example['number_of_pos_sent'].value_counts().sort_index()
# Out:
# 1     4226
# 2       80
# 3       65
# 4       37
# 5       14
# 9        9
# 10      10
# 11      11
# 19      19
# Name: number_of_pos_sent, dtype: int64

# %%
example
# Out:
#           id                                               text  \
# 20739  27116                         Imphal, September 22 2017:
# 20740  27116  Incessant rain in the past few days has severe...
# 20741  27116  While most places in the valley districts of t...
# 20742  27116  Report reaching here said that a massive lands...
# 20743  27116             Tamenglong �Khongsang road last night.
# ...      ...                                                ...
# 26128  35646  Meanwhile, the Kanchanjunga Academy Higher Sec...
# 26129  35649  Follow us on landslide blocks doda batote high...
# 26130  35649  The highway was blocked after a landslide hit ...
# 26131  35649  He said that the work to open the highway was ...
# 26132  35649  “If there is no rain, we might throw the road ...
#
#                                     location_description  \
# 20739  near the Khongjaron Khunthak village, Tamei Ro...
# 20740  near the Khongjaron Khunthak village, Tamei Ro...
# 20741  near the Khongjaron Khunthak village, Tamei Ro...
# 20742  near the Khongjaron Khunthak village, Tamei Ro...
# 20743  near the Khongjaron Khunthak village, Tamei Ro...
# ...                                                  ...
# 26128  Phidim-Raanke section of the Mechi Highway at ...
# 26129           Chakwa bridge, 9 kilomters short of Doda
# 26130           Chakwa bridge, 9 kilomters short of Doda
# 26131           Chakwa bridge, 9 kilomters short of Doda
# 26132           Chakwa bridge, 9 kilomters short of Doda
#
#                    locations               dates pos_sentence  \
# 20739                Imphal|  September 22 2017|           No
# 20740                 Noney|  the past few days|           No
# 20741      Kakching|Thoubal|                   |           No
# 20742  Inrailong|Khongjaron|                   |          Yes
# 20743  Tamenglong|Khongsang|         |last night           No
# ...                      ...                 ...          ...
# 26128              Phidim-1|                   |           No
# 26129                 Jammu|                   |           No
# 26130                  Doda|       |last evening          Yes
# 26131                      |       today|evening           No
# 26132                      |       today|evening           No
#
#        number_of_pos_sent  contain_pos_sent
# 20739                   1              True
# 20740                   1              True
# 20741                   1              True
# 20742                   1              True
# 20743                   1              True
# ...                   ...               ...
# 26128                   1              True
# 26129                   1              True
# 26130                   1              True
# 26131                   1              True
# 26132                   1              True
#
# [4471 rows x 8 columns]

# %% [markdown]
# ### 4.2 Get the predicted results

# %%
def get_distance(p1, p2):
    """Get the geographical distance between two points"""
    if p1 and p2:
        return round(geopy.distance.geodesic(p1, p2).km, 3)
    else:
        return None

# %%
def get_outlier_idx(centroid, points):
    """
    Parameters: 
        centroid: a tuple of centroid;
        points: a list of tuples
    Return:
        the index of the point that should be removed
    """
    dists = [get_distance(centroid, point) for point in points]
    return dists.index(max(dists))

# %%
def get_smallest_region_idx(locs):
    """
    Parameters
    ----------
    locs : list of dictionary
        a list of dictionary containing latitude, longitude, 
        northeast point, southwest point for all the location 
        entities in the positive sentence
    
    Returns
    ----------
        an integer indicating the index of the location entity 
        that has the smallest region
    """
    dists = [get_distance(loc['northeast'], loc['southwest']) for loc in locs]
    return dists.index(min(dists))

# %%
def get_pred_location(df, model):   # df=example, model=best_model
    """Get the most likely locations, latitude, longitude based on pred model

    Parameters
    ----------
    df: 
        a data frame containing document ID (id) and tokenized sentences (text) for each document, 
        extracted location entities (locations), and extracted date entities (dates)
    model:
        the prediction model (logistic model trained on NASA dataset)

    Returns
    -------
        a data frame with locations, the most likely location, latitude, longitude, diameter
    """
    # get predict_proba
    pd.options.mode.chained_assignment = None   # silent warning message
    df['predict_proba'] = model.predict_proba(df['text'])[:, 1]

    result = {'locations': defaultdict(str),
              'location': defaultdict(str),
              'latitude': defaultdict(float),
              'longitude': defaultdict(float),
              'diameter_km': defaultdict(float)}

    # get a dict of idxmax for each document
    idx_max = df.groupby('id')['predict_proba'].idxmax().to_dict()

    data = df.to_dict()
    for i, idx in idx_max.items():  # i: index of the document; idx: index of the df
        # ensure the `locations` column of the `idxmax` row is not empty 
        current_proba = df.query('id == @i')['predict_proba']
        while data['locations'][idx] == "|":
            try:
                current_proba = current_proba.drop(idx)  # drop the current idxmax
                idx = current_proba.idxmax()  # get the idxmax of the rest
            except ValueError:
                print(f"All locations in document {i} are empty!") 
                idx = -1  # set idx=-1 if all locations are empty
                break
        
        # store the locations, latitude, longitude in result dict
        if idx != -1:
            result['locations'][i] = data['locations'][idx]

            locs = list(filter(None, data['locations'][idx].split("|")))
            geolocs = []
            for loc in locs:
                geocoded = geocoder.arcgis(loc).json
                if geocoded:
                    geoloc = geocoded['bbox']
                    geoloc['lat'], geoloc['lng'] = geocoded['lat'], geocoded['lng']
                    geolocs.append(geoloc)
            
            if len(geolocs) > 2:
                # remove the farthest outlier
                lats, lngs = [loc['lat'] for loc in geolocs], [loc['lng'] for loc in geolocs]
                mean_lat, mean_lng = np.mean(lats), np.mean(lngs)  # get the centroid
                x = get_outlier_idx(
                    (mean_lat, mean_lng), 
                    [(lat, lng) for lat, lng in zip(lats, lngs)]
                )
                del geolocs[x]
                del locs[x]
                # get the index of location with the smallest region
                j = get_smallest_region_idx(geolocs)
                location = locs[j]
                lat, lng = geolocs[j]['lat'], geolocs[j]['lng']
                ne, sw = geolocs[j]['northeast'], geolocs[j]['southwest']
            elif len(geolocs) == 2:
                j = get_smallest_region_idx(geolocs)
                location = locs[j]
                lat, lng = geolocs[j]['lat'], geolocs[j]['lng']
                ne, sw = geolocs[j]['northeast'], geolocs[j]['southwest']
            elif len(geolocs) == 1:
                location = locs[0]
                lat, lng = geolocs[0]['lat'], geolocs[0]['lng']
                ne, sw = geolocs[0]['northeast'], geolocs[0]['southwest']
            else:
                print(f"Locations in document {i} cannot be geocoded!")
                location, lat, lng, ne, sw = None, None, None, None, None
        else:
            result['locations'][i] = None
            location, lat, lng, ne, sw = None, None, None, None, None
        
        result['location'][i] = location
        result['latitude'][i], result['longitude'][i] = lat, lng
        result['diameter_km'][i] = get_distance(ne, sw)
    
    return pd.DataFrame(result)

# %%
results = get_pred_location(example, best_model) 
results
# Out:
# All locations in document 28784 are empty!
# All locations in document 33604 are empty!
#                                                locations       location  \
# 27116                    Purul-Lakhamai|Senapati|Paokho|       Senapati
# 27117                                            Kohima|         Kohima
# 27118                                 Kot village|Tehri|    Kot village
# 27132                               West Java|Indonesia|      West Java
# 27133                                         Princeton|      Princeton
# ...                                                  ...            ...
# 35610                                         Mishawaka|      Mishawaka
# 35613                Tamenglong|Daniel Kamei Tamenglong|     Tamenglong
# 35633  Surigao del Sur|DAVAO CITY|Philippines|Surigao...     DAVAO CITY
# 35646          PAANCHTHAR|Phidim-Raanke|Samdin|Phidim-2|  Phidim-Raanke
# 35649                                             Jammu|          Jammu
#
#        latitude  longitude  diameter_km
# 27116  25.26867   94.02224        6.289
# 27117  25.66288   94.09311       13.755
# 27118  29.52405   81.58881        2.945
# 27132  -6.75000  107.50000      342.130
# 27133  40.34954  -74.66009        3.635
# ...         ...        ...          ...
# 35610  41.66017  -86.17217       15.826
# 35613  24.96538   93.49509       47.665
# 35633   7.06574  125.61080       93.480
# 35646  27.12615   87.75943        2.974
# 35649  32.70273   74.87870       28.755
#
# [555 rows x 5 columns]

# %%
results.to_dict()['locations']
# Out:
# {27116: 'Purul-Lakhamai|Senapati|Paokho|',
#  27117: 'Kohima|',
#  27118: 'Kot village|Tehri|',
#  27132: 'West Java|Indonesia|',
#  27133: 'Princeton|',
#  27151: '|the Rio Pita',
#  27179: 'Gopeshwar|Chamoli|Farkhet|Ghat|Chamoli|',
#  27186: 'Malyana|Shimla|',
#  27187: 'West Bengal|',
#  27189: 'Chittakunnu|Thrissur|',
#  27191: 'Luopu Village|Sichuan|',
#  27192: 'Cornwall|',
#  27193: 'Lochaber|',
#  27194: 'Sungai Mapai|Kanowit|',
#  27211: 'Hoàng Phú|Nha Trang City|',
#  27216: 'Hiroshima|',
#  27219: 'Florence|North Carolina|Ashe County|',
#  27220: 'Mae La Oon|Ward 1|',
#  27223: 'Folkestone|Warren|Kent|',
#  27607: 'Sogod|Mt. Panjongon',
#  27608: 'Pedreira|Sao Paulo|',
#  27610: 'Kangding|China|Sichuan Province|',
#  27627: 'China|Yunnan Province|',
#  27634: 'Othar Nala|Kohistan|',
#  27640: 'Sindhupalchowk|Sindhupalchowk|',
#  27643: 'Udhampur-Katra|Udhampur|',
#  27649: 'Sydney|Mudgee|Mudgee|Mudgee|',
#  27650: '|Western Yukon|Haines Junction|Destruction Bay|Kluane Lake',
#  27651: 'Guba|Chichi|',
#  27656: 'Rudraprayag|Uttarakhand|',
#  27669: 'Indonesia|',
#  27670: 'Buhisan|Quiot-Pardo|Cebu City|Toong',
#  27682: 'Alna|',
#  27687: 'Nuwakot|',
#  27711: 'China|Yunnan province|',
#  27716: 'Brazil|Rio de Janeiro|Serrana',
#  27720: 'MADISON COUNTY|N.C.|Madison County|',
#  27726: 'Matta tehsil|Swat|',
#  27734: '|Horcones|Confluence|Aconcagua',
#  27765: 'Totontepec Villa de Morelos|',
#  27774: 'Astor St.|',
#  27783: 'Bolinas|',
#  27789: 'Putnam Valley|',
#  27792: 'Bicol|Marambong|Pandan|Catanduanes|Gliceria delos Santos',
#  27804: 'Nepal|',
#  27808: 'Kullu|Kullu|',
#  27810: 'Givors|',
#  27815: 'Burlington County|',
#  27822: 'New Zealand|Mount Dixon',
#  27828: 'Withypool|',
#  27829: 'TAGUM CITY|Maco|Compostela Valley|',
#  27852: 'Wonosobo|Wonosobo|C Java|Garung Lor|Sukoharjo sub-district|Wonosob District|Central Java Province|',
#  27854: 'Saguenay|Chicoutimi|Saint-Fulgence|Lac-St-Jean',
#  27862: 'Antipolo City|',
#  27863: 'PHILADELPHIA|Pennsylvania|Pittsburgh|',
#  27867: 'MANILA|Philippines|Sultan Kudarat province|',
#  27871: 'Guatemala|',
#  27874: 'Naches|Yakima|',
#  27892: 'China|Fujian Province|',
#  27893: 'Gashaka|Janga Tsiri|Maluri|Fika Local Govt Area|Yobe State|',
#  27895: '|Grants Pass',
#  27896: 'Pembroke|ON|',
#  27909: 'Sidengok|Peawaran|Banjarnegara|Central Java|',
#  27912: 'Yercaud|',
#  28580: 'South Kelso|',
#  28581: '|Queen Anne',
#  28583: 'MANILA|Philippines|Philippines|Negros Oriental',
#  28587: 'Talis village|Mashabrum|Ghanche|',
#  28591: 'TEMPO.CO|Pacitan|Pacitan|East Java|Kebonagung District',
#  28594: 'Dhading|',
#  28595: 'Auckland|',
#  28601: 'Phirangipuram|Guntur|',
#  28606: 'SAN FERNANDO|Casiguran|Aurora|',
#  28613: 'Gangtok|Zang|East Sikkim|',
#  28617: 'MANILA|Philippines|Muntinlupa City|',
#  28631: 'Brugnato|Carrodano|La Spezia|',
#  28639: 'Colon province|Capira|Panama City|Caribbean',
#  28650: 'Oko Community|Anambra State|',
#  28653: 'TAGUM CITY|Talaingod|Davao del Norte|',
#  28660: 'Panimbangan village|Cisarua|Bogor|Bogor|Cipanas|Cianjur|',
#  28684: 'Munsyari|Pithoragarh|',
#  28690: 'Japan|',
#  28693: 'Kazbegi|',
#  28701: 'Scotland|',
#  28703: 'Perry River|Revelstoke|Revelstoke|',
#  28712: 'Santiago|Santo Domingo|',
#  28716: 'The Jizan Region|Saudi Arabia|Yemen|',
#  28727: 'Ekai village|Tadubi|Kambirong|Nungba|',
#  28730: 'London|Victoria|Rochester|',
#  28731: 'Nepal|',
#  28738: 'China|',
#  28743: 'Ky|Pike County|Kentucky|West Virginia|',
#  28751: "Himachal Pradesh 's|Solan|",
#  28754: 'Rowley|Topsfield|',
#  28761: 'Keragalakanda|Passara',
#  28773: '|Panian|Semirara Island|Antique',
#  28780: 'VIRAC|Catanduanes|Philippines|',
#  28784: None,
#  28796: 'Trondheim|Oslo|',
#  28802: 'Bandarban|Chittagong|',
#  28805: 'Portland|Portland|the Rio Grande Valley',
#  28807: "Hubei|Xinhua|WUHAN|Hubei province|Central China 's",
#  28812: 'San Pablo City|Laguna|',
#  28823: 'Richmond|Junction|',
#  28825: "Xinhua|Central China 's|Hubei province|",
#  28836: 'Sophia|',
#  28837: 'Field|B.C.|',
#  28842: 'Pangpangon Village|Talisayan|Misamis Oriental|',
#  28847: 'Maporomokoni|Mikindani|',
#  28850: 'Arizona Republic|Prescott|',
#  28859: 'Pailin province|',
#  28863: 'Thorpeness|Suffolk|',
#  28865: 'Mabayi|Cibitoke Province|',
#  28869: 'Bichnakandi|Gowainghat|Sylhet|',
#  28872: 'Keremeos|Kaleden|Yellow Lake',
#  28906: 'Raturi Sera|Matli|Gangotri|',
#  28912: 'Chicago|Seattle|Everett|',
#  28951: 'Honduras|',
#  28952: 'Vijaya Nagar Colony|Gunadala hill',
#  28954: 'Kuzhithurai|Eraniel|Nagercoil-Thiruvanananthapuram',
#  28957: 'Doda|the Kashtighar tehsil',
#  28958: 'Nilambur|',
#  28961: 'Man-asok|Buguias|Benguet|Philippines|',
#  28962: 'Ramshila|',
#  29586: 'Barangay Guisad Surong|Baguio City|Northern Luzon',
#  29587: 'Ifugao|',
#  29589: 'Tajikistan|Isfar|',
#  29591: 'Ropar|Dallaghat|Solan|',
#  29597: 'Chyotchyot|Lamabagar-4|Dolakha|',
#  29598: 'Palgaon|Barkot|Uttarkashi|Yamnotri|',
#  29599: 'France|',
#  29602: 'Vasind|Asangaon|Mumbai|',
#  29611: 'Flintshire|',
#  29628: 'Multnomah County|the West Hills',
#  29632: 'Pettus|Raleigh County|',
#  29639: 'Mansehra|Khyber Pakhtunkhwa|',
#  29654: 'Puti|Buhisan|Cebu City|',
#  29665: '|Lake Wohlford Rd',
#  29670: 'Songkhla|',
#  29673: 'Vietnam|Ha Giang|',
#  29684: 'Cebu City|',
#  29685: '|Elkwater',
#  29695: 'Sikkim|West Bengal|India|',
#  29697: 'Mumbai|',
#  29709: 'Mae Sot-Myawaddy|Myawaddy-Kawkareik|Karen State|Rangoon|',
#  29712: 'Seattle|Everett|',
#  29719: '|Askja',
#  29721: 'Italy|',
#  29723: 'California|',
#  29736: 'Joumol|Imphal|',
#  29743: 'Sinyi|Nantou County|Taiwan|',
#  29751: 'Mazandaran|',
#  29754: 'Takhar|Takhar|Chahe Abb',
#  29763: 'Corbett|',
#  29765: 'Suarez|Cauca province|',
#  29772: 'Istanbul|Turkey|',
#  29786: 'Taupo|',
#  29790: 'the Town of Wheatland|',
#  29801: 'Albion Terrace|',
#  29803: 'ILIGAN CITY|Kapatagan|Lanao del Norte|',
#  29806: "Papua New Guinea 's|Chimbu Province|",
#  29808: '|Granite Creek',
#  29813: 'Palermo|Italy|',
#  29814: 'Udhampur|The Amarnath yatra',
#  29820: 'Juiz de Fora|Belo Horizonte|Minas Gerais|',
#  29823: 'Brazil|Guaraciaba|Sao Paulo|',
#  29828: 'Jamestown|Boulder|Main St',
#  29829: 'I-5|Bellingham|',
#  29847: 'Gandara|Samar|',
#  29851: 'US|',
#  29862: 'Benguet|',
#  29873: 'Gyulezi|Guba|',
#  29874: 'Sofia|Greece|Dupnitsa|Greece|',
#  29876: '|Central Sulawesi',
#  29891: 'West Garo Hills|',
#  29893: 'MEXICO CITY|Puebla|',
#  29898: '|River Rock',
#  29899: '|the Mendocino National Forest',
#  29900: 'Fairfax|Baywood Canyon',
#  29904: 'Uttarakhand|Sirobagad|Kumaon',
#  29914: 'Calaveras County|',
#  29915: 'Rampur|Kashapat|Rampur|Shimla|',
#  29926: '|Naveiwakau ’s Creek',
#  29931: 'TEMPO.CO|Jakarta|Tugu Selatan|Cisarua|Bogor|',
#  29941: 'Indonesia|Java Island',
#  29942: 'Ystalyfera|',
#  29943: 'Omokoroa|',
#  29972: '|Sawyers Bay|Blanket Bay',
#  29981: 'TAIPEI|China|Hubei Province|Three Gorges',
#  29982: 'Charmouth Beach|',
#  30020: 'Himachal Pradesh|Bilaspur|',
#  30021: 'Gianyar|Bali|Pacitan|East Java|',
#  30022: 'Kangra|',
#  30027: '|San Ysidro Creek',
#  30582: 'Sarawak|Jalan Sibu-Bintulu',
#  30584: 'Takdoo|',
#  30587: 'Teknaf|Teknaf upazila|',
#  30590: 'Joshimath|Badrinath|Chamoli|Uttarakhand|',
#  30594: 'Bekenu|',
#  30612: 'Sahong|Tabu|Pani village|Tadubi|Senapati|',
#  30628: 'Clatskanie|Columbia County|',
#  30632: 'California|Olancha|Dunmovin|',
#  30634: 'Bududa|Uganda|',
#  30635: 'Itanagar|',
#  30661: 'Ferrara|Torrox|Malaga|Spain|',
#  30662: 'Lang Son Province|',
#  30669: 'CEBU CITY|Philippines|Cebu City|',
#  30678: '|Klamath River|Northern California',
#  30679: 'Chaffee County|Cottonwood Lake|Buena Vista|',
#  30681: 'Carlton|Texas Creek',
#  30685: 'St-Jude|',
#  30687: 'Trikuta Hills|Reasi|Jammu|Kashmir',
#  30690: 'Montreal|',
#  30692: 'Stevenson|Skamania County|',
#  30711: 'Shimla|New Shimla|Vikasnagar|East Shimla|',
#  30712: 'Tukaraki|Ba|',
#  30727: 'Gillingham|Dorset|',
#  30728: 'Sitio|Bangbang Calizo|Balete|Aklan|',
#  30746: 'Dadong Village|Baise City|',
#  30763: 'Ala .|Atalla|',
#  30767: 'San Jose|Caldera|Atenas|Orotina|',
#  30775: 'Vietnam|Lekima|',
#  30784: 'Gammom|Chamu village|Kamjong|Ukhrul|',
#  30786: 'YANGON|Myanmar|',
#  30789: 'Mexico|',
#  30791: 'Jammu|Kashmir|the Tsarap River|the Phuktal River',
#  30812: 'Calvert County|',
#  30819: "Yan'an City|China|Shaanxi Province|",
#  30822: 'Guangyuan|Sichuan|',
#  30826: 'Leyte|Seniang TACLOBAN CITY|Philippines|UPDATED|Tanauan|Leyte|',
#  30834: 'Canlanpay|Carigara|Leyte|',
#  30838: 'Rossbeigh|',
#  30840: 'Shuangqiao Village|Liuyang|Changsha|',
#  30841: 'Rongsak|Bansamgre|East Garo Hills',
#  30844: 'Lovedale|',
#  30846: 'CEBU CITY|Philippines|Central Visayas|',
#  30851: "Costa Rica 's|Main Port|",
#  30857: 'BEIJING|China|Sichuan province|',
#  30861: 'Guo-Ji|Tucheng City|Taipei county|',
#  30864: 'Puerto Galera|Oriental Mindoro',
#  30869: '|Aspen',
#  30870: 'Port Townsend|',
#  30873: 'Peachland|',
#  30874: 'Bududa|',
#  30875: 'Colombia|Hidroituango|Colombia|Ituango|Ituango',
#  30894: 'Vettikuzhi|Athirappilly|Chalakudy|',
#  30895: "Arecibo|Puerto Rico 's|",
#  30897: 'Tuolumne County|',
#  30898: 'Vidyagiri Residency|Nagarbhavi|',
#  31581: 'Malshej|Mumbai|Murbad taluka',
#  31599: 'Turkey|Syria|',
#  31601: 'Peru|Zurite district',
#  31612: 'Polangui|Mount Masaraga',
#  31620: 'Nebraska|',
#  31621: 'MANILA|Philippines|Patilong|Banaue|Ifugao province|',
#  31625: 'Indonesia|',
#  31628: 'Darchula|Darchula|',
#  31632: 'LUCENA CITY|Binangonan|Rizal|Southern Luzon',
#  31639: 'Oranovo|Simitli|',
#  31640: 'S .|DAVAO CITY|',
#  31642: 'Myanmar|',
#  31643: 'Colchester|',
#  31644: 'C Java|Purworejo District|Central Java|',
#  31646: 'Kasara|Igatpuri|',
#  31649: 'Panjtirthi|',
#  31654: 'CANBERRA|Jan 24|Papua New Guinea|',
#  31660: 'Nagasaki Prefecture|Oita Prefecture|',
#  31667: 'Barnehurst|Bexleyheath|',
#  31670: 'Villa Hills|',
#  31671: 'Visakhapatnam|',
#  31675: 'Raleigh County|',
#  31679: 'Rizal|',
#  31683: '|Meall Cumhann',
#  31686: 'Falkland|Zemabawk|Aizawl|',
#  31691: 'Khandala|',
#  31698: 'ECoR|Dumriput|Damanjodi|Koraput-Rayagada',
#  31706: "GUILIN|Guangxi|South China 's|Guangxi Zhuang Autonomous Region|",
#  31714: 'Squamish|',
#  31726: 'Bameng-Chayang Tajo|Mebua,hardly|Seppa|East Kameng district',
#  31738: 'Azerbaijan|Baku|Tovuz',
#  31740: 'Imphal|',
#  31751: 'TAIPEI|',
#  31756: '|the Kandy District',
#  31757: 'GNA Hohoe|GNA|Kable-Todzi|Gbi-Akplamafu|Hohoe District|',
#  31760: 'Baguio City|Capas|Tarlac|Botolan|Zambales , Bautista town|Pangasinan|Mandaluyong City|',
#  31780: 'Guangzhou|Shenzhen|China|Guangdong|',
#  31784: 'Belmont|Baptiste Lane|',
#  31787: 'Chumpon|',
#  31790: 'China|Hong Kong|Guangdong|',
#  31792: 'Buller|Lamplough Stream|',
#  31798: 'Maram|Senapati|Maram|Senapati|',
#  31804: 'Santa Clara County|Los Gatos|',
#  31809: "China|Xinhua|CHENGDU|Sichuan province|Southwest China 's",
#  31810: 'Sakinaka|',
#  31820: 'Corbett|',
#  31822: 'Pahalagama|Udawatte|Hanguranketha|',
#  31824: 'Uttarakhand|Dharchula|',
#  31825: 'Kampung Cimerak|Tegalpanjang village|Cireunghas|Sukabumi|West Java|',
#  31826: 'China|Sichuan|',
#  31829: 'Itanagar|Arunachal Pradesh|',
#  31848: 'El Salvador|',
#  31860: 'Haima|the Cordillera Administrative Region|Northern Luzon',
#  31865: 'Virginia City|',
#  31869: 'Canby|',
#  31876: 'Coonoor|Mettupalayam|Adderlie|',
#  31877: 'Lead|',
#  31880: 'Broadsea|Fraserburgh|',
#  31884: 'Tibet|Sichuan|',
#  31887: '|the Via Aurelia',
#  31894: '|the Eel River',
#  31902: 'el Pedregal|Amatitlan|Guatemala|',
#  31913: 'MANILA|Philippines|Antipolo City|Rizal|',
#  31918: 'Inverness|',
#  31929: 'Upparavagu|One Town|',
#  31937: 'Oppland|Norway|',
#  31953: 'Doli|',
#  31955: 'Sioux City|',
#  31957: '|Denali National Park',
#  31964: 'Catanduanes province|',
#  31965: '|Constellation Cove|Tai Po Kau',
#  31982: 'Zuangtui|Aizawl|',
#  31991: 'East Tuawo|Hulawalu|Bukit Aren',
#  31996: 'North Petherton|',
#  32001: '|Camel Rock',
#  32019: 'Fremont|Tenaya',
#  32021: 'Santa Clara County|Morgan Hill|',
#  32022: '|Lake Berryessa',
#  32023: 'Norway|Castro Creek Canyon',
#  32028: 'GREENBRAE|CA|Greenbrae|',
#  32035: 'Papeete|Tahiti|',
#  32042: 'Sicamous|',
#  32043: 'Selangor|Hulu Langat',
#  32047: 'Dargaville|',
#  32050: 'West Auckland|',
#  32057: 'Coimbatore|Coonoor|',
#  32058: 'Tuba|Benguet|Maundy|',
#  32072: 'Burma|',
#  32074: 'Olympia|Washington|',
#  32118: 'Dover|Faversham|',
#  32120: 'Kohima|Mewoboke|Khuzama|',
#  32121: 'Malidor|East Jaintia Hills|',
#  32126: 'Cisarua|Bogor|',
#  32128: 'Anglesey|',
#  32129: 'Saundersfoot|',
#  32137: 'Bohol|Barangay Cayam',
#  32138: 'TAIPEI|Taitung County|Zhiben|',
#  32157: 'Philippines|Naga City|Cebu|',
#  32174: 'Philippines|Natonin|Mountain Province|Barangay Banawel|',
#  32176: 'Puttila|Bilinele|Puttur|',
#  32180: 'Kamala|KAMALA FLOODINGA',
#  32183: 'West Somerset|',
#  32584: 'Fukushima|',
#  32590: 'Diva|Kalwa|',
#  32596: 'LANZHOU|China|Gansu Province|',
#  32611: 'Durango|Bondad Hill',
#  32618: 'Victoria|',
#  32619: 'Mastamandu|Nepal|',
#  32629: 'Koramangala|',
#  32632: 'Benton County|Wren|North Albany|Woods Creek',
#  32638: 'Japan|Hiroshima|',
#  32645: 'Shimla|Himachal Pradesh|Kinnaur|',
#  32646: 'SHIMLA|Kinnaur|',
#  32647: 'Sao Paulo|Brazil|Sao Paulo|Brazil|',
#  32650: 'Kebumen|the Kaligending Village|Karangsambung , Kebumen District|Central Java|Central Java',
#  32652: 'Bournemouth|',
#  32668: 'Kumbiron|',
#  32679: 'Adoshi|Khopoli|',
#  32683: 'Lumle|',
#  32684: 'Newcastle|Carlisle|',
#  32693: 'Tegucigalpa|Los Pinos|',
#  32704: 'Kapkot|Bageshwar|',
#  32712: 'Baramulla|Kashmir',
#  32718: 'GILGIT|',
#  32722: 'Karori|Nottingham St',
#  32737: 'Grindrod|Sicamous|',
#  32740: 'Etalin|Anelih|Arzoo|Etalin|',
#  32743: 'Badulla|the Badulla District',
#  32750: 'West Quebec|Chelsea|',
#  32751: 'Gaoyuan|Guiding county|',
#  32753: 'Washington|',
#  32795: 'Bududa|',
#  32796: 'Bryce Canyon City|',
#  32797: 'Itogon|',
#  32815: 'Sulawesi|',
#  32819: 'Arizona|Cold Springs',
#  32824: 'Valook|',
#  32827: 'Chinnapallam|Kodaikanal|',
#  32828: 'Jharkhand|Yedappalli|Coonoor|Nilgiris',
#  32830: 'Seixal|',
#  32831: 'Begur|North Wayanad',
#  32832: 'COVINGTON|Covington|',
#  32833: 'Chamba|Himachal Pradesh|Manimahesh',
#  32838: 'Treherbert|Porth|',
#  32839: 'Tekoa|',
#  32841: '|Monte Antelao slopes|Dolomites|North Eastern Italy',
#  32846: 'Itogon|Benguet|Philippines|',
#  32848: 'Shimla-Hatkoti|Patti Dhank|Kotkhai|Kharapathar|',
#  32849: 'Helmsdale|',
#  32851: 'Thrissur|Kuthiran|',
#  32852: 'Batswat village|Tehsil Ishkoman , District Ghizer|Gilgit Baltistan',
#  32864: 'Thuampui|Ainawn|Aizawl|',
#  33580: 'Lombok|',
#  33582: 'Chandrapur|',
#  33585: 'Indonesia|Pondok Labu|Jakarta|',
#  33586: 'Erdaoban|China|',
#  33589: 'Himachal Pradesh|Baddi|Chandigarh|',
#  33590: 'Volcan|Argentina|',
#  33597: 'Meru|',
#  33603: 'Vancouver|Sea',
#  33604: None,
#  33611: 'MEXICO CITY|Sputnik|Quibdo|Colombia|',
#  33627: "China|Xinhua|KUNMING|Southwest China 's|Yunnan province|",
#  33657: 'Chamba|Himachal Pradesh|',
#  33675: 'Hpa-saung|Kayah|',
#  33682: 'Manila|Chittagong city|',
#  33683: 'Bhutan|',
#  33689: 'CHONGQING|Yunyang County|China|Chongqing Municipality|',
#  33695: 'Kampung Menggaris|',
#  33698: '|Taman Terubong Jaya|Paya Terubong',
#  33705: 'Yilan County|',
#  33714: 'San José|Limón|Caribbean',
#  33734: 'Licuan-Baay|',
#  33740: 'Davenport|Santa Cruz County|',
#  33741: '|Wai-ora Trust-owned',
#  33748: 'Morobe|Apayata|Watut',
#  33751: '|Central California',
#  33758: 'Galena|Incline|',
#  33761: 'Nabiganj|Sankarsena|',
#  33766: 'Sabah|Tongod|Milian',
#  33767: 'RENTON|WA|Renton|',
#  33768: 'Dayakan village|Ponorogo|East Java|',
#  33773: 'Lamlyer|Mawlyngngad|East Khasi Hills|',
#  33774: 'Seattle|Portland|Felida|Clark County|',
#  33775: 'British Columbia|Creston|',
#  33777: 'Jammu|Tehri|Kashmir',
#  33790: 'Awan Village|',
#  33794: 'Hpakant|',
#  33797: 'Kandal|Tonle Bassac',
#  33798: 'Glenn County|Oroville|Dunstone|Teddy|',
#  33803: 'Dalgate|Kashmir',
#  33806: 'Nanzhang County|China|Hubei Province|',
#  33808: '|PROVO CANYON|Provo Canyon',
#  33809: 'Tlungvel|Mizoram|Aizawl|',
#  33810: 'Rossinver|Sligo-Roscommon|',
#  33813: 'Shimla|',
#  33814: 'Jambi|Rantau Pandan|Bungo|Rantau Pandan|Rantau Duku',
#  33821: 'Renton|',
#  33822: 'Guwahati|Assamâ|West Karbi Anglong',
#  33823: 'Indonesia|West Sumatra|',
#  33838: "Tharaka Nithi|Murang'a county - Rains|",
#  33840: 'Neath|Port Talbot|',
#  33844: 'Gardenstown|Seatown|',
#  33847: 'Simbai|Madang|Middle Ramu',
#  33852: 'Idukki|Malappuram|Kannur|Wayanad|',
#  33915: 'Chesapeake|Lawrence County|Ohio|',
#  33916: 'Yangon|Homalin Township , Sagaing Region|',
#  33918: '|Arenal Volcano',
#  33931: 'Sitka|',
#  33933: 'Bakersfield|',
#  33963: 'Haena|North Shore|Wainiha',
#  33964: 'Lundin|Sweden|',
#  33966: 'Barangay Busay|Cebu City|',
#  33967: '|The Regional District of Central Kootenay',
#  33970: 'Kabardino-Balkaria|Elbrus|Elbrus District',
#  33972: 'Lagonoy , Camarines Sur|Guibahoy|',
#  34001: 'Chiang Rai|Phu Chi Fah',
#  34009: 'London|',
#  34010: 'Baraghara|Gangabada|Rayagada|',
#  34011: 'Pallivasal|Munnar|',
#  34016: 'Malappuram|Kerala|Malappuram|',
#  34020: 'Scrabster|',
#  34024: 'Harwood|',
#  34027: 'Nepal|',
#  34596: 'Steele Creek|CHARLOTTE|N.C|Steele Creek',
#  34598: 'Baduraliya|',
#  34599: 'Saikul|Kangpokpi|',
#  34601: 'Bali Nallah|Udhampur|Nashri|Ramban|',
#  34607: 'China|',
#  34609: 'Naltar|Kargah|Gooro|',
#  34612: '|Askja',
#  34621: 'Port Susan|',
#  34624: 'Chitral|Oveer valley',
#  34634: 'Chaguaramas|West',
#  34639: 'Barangay San Jose|',
#  34642: 'Narok|Kenya|Narok|Enakishomi|',
#  34657: 'Georgia|Tbilisi|Tskneti|Betania|',
#  34658: 'Calstock|',
#  34661: 'Indrakeeladri|',
#  34662: 'Imphal|Imphal|Imphal|Dimapur|Nagaland|',
#  34667: 'Northern Ireland|Spain|',
#  34676: 'Vintage Hills|',
#  34678: 'Ortum|Kerelwa|Batei Ward|',
#  34679: 'Khandala|',
#  34699: 'Koronadal City|',
#  34704: 'Kankumbi|Karnataka|',
#  34705: 'Hpakant|Kachin|',
#  34715: 'Balughat|Sylhet|Gowainghat|',
#  34719: '|Udaipur-Ahmedabad',
#  34723: 'Mukilteo|Everett|',
#  34726: 'New Plymouth|Tikorangi|Otaraoa Rd|Mangahewa Rd',
#  34731: 'Bulgaria|Mezdra|',
#  34734: 'Guatemala|',
#  34749: 'Lefkada|the Egremni Beach',
#  34754: 'China|Guangxi Zhuang Autonomous Region|',
#  34756: 'Maguindanao|Bukidnon|',
#  34757: '|Pagla Jhora',
#  34759: 'Gilgit-Baltistan|Kohistan|Chilas|',
#  34768: 'ILOILO CITY|Philippines|Alimodian|Iloilo|Western Visayas',
#  34771: 'Dhubri|',
#  34779: 'Phuket|Phuket Landslip|Andaman',
#  34783: 'KALIKOT|Manma|Kalikot|',
#  34793: 'Kern County|',
#  34797: 'Umri village|',
#  34800: "Famla village|Arunachal Pradesh 's|Tawang|",
#  34807: 'Dar Al-Salam|Umm Durman City|Sudan|',
#  34808: "South Delhi 's|East Kidwai Nagar|",
#  34826: '|Taman Taiping Villa',
#  34829: 'MEXICO CITY|',
#  34838: '|The Town of Peace River|Peace River',
#  34852: 'CHIANG RAI|Chiang Rai|',
#  34855: 'Kampung Gambaron|',
#  34858: 'Mexico|Oaxaca|',
#  34870: 'China|Guizhou Province|',
#  34879: 'Omoeroa|South Island',
#  34881: 'Yolo County|',
#  34882: 'Orinda|',
#  34883: '|West Coast',
#  34897: 'Barlekha|Barlekha upazila|Moulvibazar|',
#  34901: 'Kishtwar|Kuligardh Drabshallah',
#  34902: '|River Road South',
#  34904: '|Eagle Bay',
#  34905: 'St Mary|',
#  34906: 'Bajhang|',
#  34907: 'Samoa|Malota|',
#  34911: 'Kallar|Hillgrove|',
#  34918: 'Karinchola|Kerala|',
#  34947: 'Thodupuzha|Idukki|',
#  34962: 'Tibet|Nyingchi|',
#  34974: 'Guobu|China|',
#  34976: 'Upputhodu|Thopramkudy|Idukki|',
#  34977: '|Big Sur',
#  34978: 'Wisconsin|Oak Creek|Wisconsin|',
#  34980: 'Kamloops|Merritt|Campbell Creek|Separation|',
#  34984: 'Tafua-tai|Savaii island',
#  35581: '|Maggie Valley',
#  35584: 'Sylmar|San Fernando Valley',
#  35592: 'Darkha VDC-8|Dhading|',
#  35598: 'Darjeeling|',
#  35606: 'SANTOS CITY|MindaNews|Tampakan|South Cotabato|',
#  35609: 'Lalunggaon|',
#  35610: 'Mishawaka|',
#  35613: 'Tamenglong|Daniel Kamei Tamenglong|',
#  35633: 'Surigao del Sur|DAVAO CITY|Philippines|Surigao del Sur|',
#  35646: 'PAANCHTHAR|Phidim-Raanke|Samdin|Phidim-2|',
#  35649: 'Jammu|'}

# %%
results.size
# Out:
# 2775

# %% [markdown]
# ### 4.3 Evaluate the results

# %%
nasa = pd.read_csv("../data/nasa_global_landslide_catalog_point.csv")
nasa = nasa.rename(columns={"latitude": "gold_latitude", "longitude": "gold_longitude"})  # id: index in NASA dataset

# %%
eval_df = results.join(nasa[['location_description', 'location_accuracy', 'gold_latitude', 'gold_longitude']])
eval_df
# Out:
#                                                locations       location  \
# 27116                    Purul-Lakhamai|Senapati|Paokho|       Senapati
# 27117                                            Kohima|         Kohima
# 27118                                 Kot village|Tehri|    Kot village
# 27132                               West Java|Indonesia|      West Java
# 27133                                         Princeton|      Princeton
# ...                                                  ...            ...
# 35610                                         Mishawaka|      Mishawaka
# 35613                Tamenglong|Daniel Kamei Tamenglong|     Tamenglong
# 35633  Surigao del Sur|DAVAO CITY|Philippines|Surigao...     DAVAO CITY
# 35646          PAANCHTHAR|Phidim-Raanke|Samdin|Phidim-2|  Phidim-Raanke
# 35649                                             Jammu|          Jammu
#
#        latitude  longitude  diameter_km  \
# 27116  25.26867   94.02224        6.289
# 27117  25.66288   94.09311       13.755
# 27118  29.52405   81.58881        2.945
# 27132  -6.75000  107.50000      342.130
# 27133  40.34954  -74.66009        3.635
# ...         ...        ...          ...
# 35610  41.66017  -86.17217       15.826
# 35613  24.96538   93.49509       47.665
# 35633   7.06574  125.61080       93.480
# 35646  27.12615   87.75943        2.974
# 35649  32.70273   74.87870       28.755
#
#                                     location_description location_accuracy  \
# 27116  near the Khongjaron Khunthak village, Tamei Ro...              10km
# 27117         P.R. Hill, Kohima, Nagaland 797005, India.               1km
# 27118  SH-8, Tehri Sub-District, Tehri Garhwal, Uttar...               1km
# 27132  Cipelah, Rancabali, Bandung, West Java, Indone...               5km
# 27133  Mountainside, off of Highway 5A, 8 miles from ...               1km
# ...                                                  ...               ...
# 35610  On County Road 27 -- The Stove Prairie Road --...               5km
# 35613                              Tamenglong Ward No-IV              50km
# 35633                         Balibadon, Surigao del Sur               5km
# 35646  Phidim-Raanke section of the Mechi Highway at ...              10km
# 35649           Chakwa bridge, 9 kilomters short of Doda               5km
#
#        gold_latitude  gold_longitude
# 27116      24.938948       93.496837
# 27117      25.658708       94.098536
# 27118      30.359485       78.377428
# 27132      -7.190355      107.289860
# 27133      49.526485     -120.521235
# ...              ...             ...
# 35610      40.655800     -105.374200
# 35613      24.981800       93.514200
# 35633       9.234000      126.169600
# 35646      27.100500       87.783100
# 35649      33.126100       75.448100
#
# [555 rows x 9 columns]

# %%
eval_df['location_accuracy'].value_counts()
# Out:
# 5km        167
# 1km        137
# 10km        76
# 25km        70
# exact       49
# 50km        32
# unknown     24
# Name: location_accuracy, dtype: int64

# %%
def get_distance2(pred_lat, pred_lng, gold_lat, gold_lng):
    if pd.isnull(pred_lat):
        return None
    else:
        return round(geopy.distance.geodesic((pred_lat, pred_lng), (gold_lat, gold_lng)).km, 3)

def get_correct1(pred_lat, pred_lng, gold_lat, gold_lng):
    """return a boolean that indicates whether the prediction result is correct"""
    if pd.isnull(pred_lat):
        return False
    else:
        if round(pred_lat) == round(gold_lat) or round(pred_lng) == round(gold_lng):
            return True
        else:
            return False

def get_correct2(accuracy, distance):
    output = False
    if accuracy == 'exact' and distance <= 20:
        output = True
    if accuracy == 'unknown' and distance <= 100:
        output = True
    if accuracy.endswith('km'):
        if distance <= float(accuracy[:-2]):
            output = True 
    return output

eval_df = eval_df.assign(distance_km=eval_df.apply(lambda x: get_distance2(x.latitude, x.longitude, x.gold_latitude, x.gold_longitude), axis=1))
eval_df = eval_df.assign(correct1=eval_df.apply(lambda x: get_correct1(x.latitude, x.longitude, x.gold_latitude, x.gold_longitude), axis=1))
eval_df = eval_df.assign(correct2=eval_df.apply(lambda x: get_correct2(x.location_accuracy, x.distance_km), axis=1))
    
eval_df
# Out:
#                                                locations       location  \
# 27116                    Purul-Lakhamai|Senapati|Paokho|       Senapati
# 27117                                            Kohima|         Kohima
# 27118                                 Kot village|Tehri|    Kot village
# 27132                               West Java|Indonesia|      West Java
# 27133                                         Princeton|      Princeton
# ...                                                  ...            ...
# 35610                                         Mishawaka|      Mishawaka
# 35613                Tamenglong|Daniel Kamei Tamenglong|     Tamenglong
# 35633  Surigao del Sur|DAVAO CITY|Philippines|Surigao...     DAVAO CITY
# 35646          PAANCHTHAR|Phidim-Raanke|Samdin|Phidim-2|  Phidim-Raanke
# 35649                                             Jammu|          Jammu
#
#        latitude  longitude  diameter_km  \
# 27116  25.26867   94.02224        6.289
# 27117  25.66288   94.09311       13.755
# 27118  29.52405   81.58881        2.945
# 27132  -6.75000  107.50000      342.130
# 27133  40.34954  -74.66009        3.635
# ...         ...        ...          ...
# 35610  41.66017  -86.17217       15.826
# 35613  24.96538   93.49509       47.665
# 35633   7.06574  125.61080       93.480
# 35646  27.12615   87.75943        2.974
# 35649  32.70273   74.87870       28.755
#
#                                     location_description location_accuracy  \
# 27116  near the Khongjaron Khunthak village, Tamei Ro...              10km
# 27117         P.R. Hill, Kohima, Nagaland 797005, India.               1km
# 27118  SH-8, Tehri Sub-District, Tehri Garhwal, Uttar...               1km
# 27132  Cipelah, Rancabali, Bandung, West Java, Indone...               5km
# 27133  Mountainside, off of Highway 5A, 8 miles from ...               1km
# ...                                                  ...               ...
# 35610  On County Road 27 -- The Stove Prairie Road --...               5km
# 35613                              Tamenglong Ward No-IV              50km
# 35633                         Balibadon, Surigao del Sur               5km
# 35646  Phidim-Raanke section of the Mechi Highway at ...              10km
# 35649           Chakwa bridge, 9 kilomters short of Doda               5km
#
#        gold_latitude  gold_longitude  distance_km  correct1  correct2
# 27116      24.938948       93.496837       64.362      True     False
# 27117      25.658708       94.098536        0.714      True      True
# 27118      30.359485       78.377428      323.556      True     False
# 27132      -7.190355      107.289860       53.952      True     False
# 27133      49.526485     -120.521235     3698.089     False     False
# ...              ...             ...          ...       ...       ...
# 35610      40.655800     -105.374200     1612.212     False     False
# 35613      24.981800       93.514200        2.652      True      True
# 35633       9.234000      126.169600      247.582      True     False
# 35646      27.100500       87.783100        3.686      True      True
# 35649      33.126100       75.448100       71.004      True     False
#
# [555 rows x 12 columns]

# %%
print(f"Prediction accuracy according to location_accuracy: {eval_df['correct2'].sum()/len(eval_df)}")
# Out:
# Prediction accuracy according to location_accuracy: 0.25765765765765763

# %%
print(f"lat/lng match accuracy: {eval_df['correct1'].sum()/len(eval_df)}")
# Out:
# lat/lng match accuracy: 0.6252252252252253

# %%
column = eval_df['distance_km']
print(f"Ratio of result within 200 km to the gold: {column[column < 200].count()/len(eval_df)}")
# Out:
# Ratio of result within 200 km to the gold: 0.6108108108108108

# %%
len(eval_df)
# Out:
# 555
