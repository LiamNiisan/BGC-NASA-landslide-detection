# %%
import os
import json
import pandas as pd
import numpy as np
from tqdm import tqdm
import geopy.distance
import geocoder
import inflect

p = inflect.engine()
pd.options.plotting.backend = "plotly"

# %% [markdown]
# _This notebook shows how the training dataset used to train the multitask BERT model used for landslide event extraction was generated._

# %%
DATA_PATH = os.path.join(
    os.path.dirname(os.path.abspath("__file__")), os.pardir, "data", "processed"
)

# %% [markdown]
# ## Import and merge data

# %%
nasa_all_df = pd.read_csv(os.path.join(DATA_PATH, os.pardir, "nasa", "nasa_global_landslide_catalog_point.csv"))
nasa_articles_df = pd.read_csv(os.path.join(DATA_PATH, "nasa_filtered.tsv"), sep="\t")
nasa_time_df = pd.read_csv(os.path.join(DATA_PATH, "time_training_data.csv"), index_col=0)
nasa_loc_df = pd.read_csv(os.path.join(DATA_PATH, "train_set_location.csv"), index_col=0)

# %%
nasa_dates_df = pd.read_csv(os.path.join(DATA_PATH, "news_text.csv"))
nasa_articles_df["article_publish_date"] = nasa_dates_df["dates"]

# %%
nasa_all_df.columns
# Out:
# Index(['OBJECTID', 'Shape', 'source_name', 'source_link', 'event_id',
#        'event_date', 'event_time', 'event_title', 'event_description',
#        'location_description', 'location_accuracy', 'landslide_category',
#        'landslide_trigger', 'landslide_size', 'landslide_setting',
#        'fatality_count', 'injury_count', 'storm_name', 'photo_link',
#        'comments', 'event_import_source', 'event_import_id', 'latitude',
#        'longitude', 'country_name', 'country_code', 'admin_division_name',
#        'gazetteer_closest_point', 'gazetteer_distance', 'submitted_date',
#        'last_edited_date'],
#       dtype='object')

# %%
nasa_df = pd.merge(
    nasa_all_df[
        [
            "event_id",
            "event_date",
            "event_time",
            "latitude",
            "longitude",
            "location_description",
            "location_accuracy",
            "landslide_category",
            "landslide_trigger",
            "fatality_count",
            "country_name",
            "admin_division_name",
            "gazetteer_closest_point",
        ]
    ],
    nasa_articles_df,
    how="inner",
    left_index=True,
    right_on="id",
).reset_index(drop=True)

nasa_df["landslide_trigger"] = nasa_df["landslide_trigger"].str.lower()
nasa_df["landslide_trigger"] = nasa_df["landslide_trigger"].map(
    lambda x: np.nan
    if x == "other" or x == "no_apparent_trigger" or x == "unknown"
    else x
)
nasa_df["landslide_category"] = nasa_df["landslide_category"].str.lower()
nasa_df["landslide_category"] = nasa_df["landslide_category"].map(
    lambda x: np.nan if x == "other" or x == "unknown" else x
)

nasa_df["article_publish_date"] = nasa_df["article_publish_date"].fillna("")
nasa_df["source_link"] = nasa_df["source_link"].fillna("")
nasa_df["landslide_category"] = nasa_df["landslide_category"].fillna("")
nasa_df["landslide_trigger"] = nasa_df["landslide_trigger"].fillna("")

nasa_df.shape
# Out:
# (3216, 24)

# %%
nasa_df["landslide_trigger"].value_counts()
# Out:
# downpour                   1100
# rain                        871
#                             452
# continuous_rain             288
# tropical_cyclone            154
# monsoon                      64
# snowfall_snowmelt            63
# construction                 60
# mining                       52
# flooding                     41
# earthquake                   33
# leaking_pipe                 14
# freeze_thaw                  12
# dam_embankment_collapse      10
# volcano                       2
# Name: landslide_trigger, dtype: int64

# %%
nasa_df["landslide_category"].value_counts()
# Out:
# landslide              2104
# mudslide                631
# rock_fall               245
# debris_flow              91
# complex                  54
#                          35
# creep                    14
# riverbank_collapse       13
# translational_slide      11
# snow_avalanche            5
# rotational_slide          5
# earth_flow                4
# lahar                     4
# Name: landslide_category, dtype: int64

# %%
import plotly.express as px

fig = px.bar(
    nasa_df["landslide_trigger"]
    .str.replace("_", " ")
    .apply(lambda x: '""' if x == "" else x)
    .value_counts()
    .reset_index()
    .iloc[::-1],
    x="landslide_trigger",
    y="index",
    labels={
        "landslide_trigger": "Trigger Count",
        "index": "Trigger Type",
    },
    color_discrete_sequence=["PeachPuff"],
    template="plotly_white"
)
fig.show()

# %%
import plotly.express as px

fig = px.bar(
    nasa_df["landslide_category"]
    .str.replace("_", " ")
    .apply(lambda x: '""' if x == "" else x)
    .value_counts()
    .reset_index()
    .iloc[::-1],
    x="landslide_category",
    y="index",
    labels={
        "landslide_category": "Category Count",
        "index": "Category Type",
    },
    color_discrete_sequence=["PeachPuff"],
    template="plotly_white"
)
fig.show()

# %%
nasa_all_df["location_accuracy"]
# Out:
# 0            5km
# 1        unknown
# 2           50km
# 3          exact
# 4            1km
#           ...
# 35647       25km
# 35648       25km
# 35649        5km
# 35650       50km
# 35651       25km
# Name: location_accuracy, Length: 35652, dtype: object

# %%
nasa_df
# Out:
#       event_id                               location_description  \
# 0         6949  Dabhol village of Maharashtra's Ratnagiri dist...
# 1         7378                                    Ghizar District
# 2         6852                                         Montenegro
# 3         7392                Interstate 5 in the Fort Tejon area
# 4         9423                        Milkbank, Portland, Jamaica
# ...        ...                                                ...
# 3211      5081  On County Road 27 -- The Stove Prairie Road --...
# 3212      7279                              Tamenglong Ward No-IV
# 3213      6657                         Balibadon, Surigao del Sur
# 3214      9185  Phidim-Raanke section of the Mechi Highway at ...
# 3215      6374           Chakwa bridge, 9 kilomters short of Doda
#
#      landslide_category landslide_trigger  fatality_count   country_name  \
# 0             landslide          downpour            12.0          India
# 1             rock_fall        earthquake             4.0       Pakistan
# 2             landslide          downpour             0.0     Montenegro
# 3              mudslide          downpour             0.0  United States
# 4              mudslide              rain             0.0        Jamaica
# ...                 ...               ...             ...            ...
# 3211          landslide          downpour             0.0  United States
# 3212           mudslide           monsoon             0.0          India
# 3213          landslide   continuous_rain             0.0    Philippines
# 3214          rock_fall               NaN             0.0          Nepal
# 3215          landslide               NaN             0.0          India
#
#      admin_division_name gazetteer_closest_point     id  \
# 0            Maharashtra              Mahar Wari      0
# 1         Northern Areas                   Gupis      1
# 2                  Budva                   Budva      6
# 3             California               Grapevine      9
# 4               Portland             Manchioneal     11
# ...                  ...                     ...    ...
# 3211            Colorado         Cache la Poudre  35610
# 3212             Manipur             Brail Range  35613
# 3213     Surigao del Sur                  Burgos  35633
# 3214               Mechi                  Beteni  35646
# 3215   Jammu and Kashmir                    Doda  35649
#
#                                             source_link  \
# 0     http://www.dnaindia.com/india/report-ratnagiri...
# 1     http://pamirtimes.net/2015/10/26/earthquake-af...
# 2     http://www.euronews.com/nocomment/2015/03/10/m...
# 3     http://www.latimes.com/local/weather/la-me-ln-...
# 4     http://jamaica-star.com/article/news/20160425/...
# ...                                                 ...
# 3211  http://www.reporterherald.com/ci_23649025/weat...
# 3212  http://e-pao.net/GP.asp?src=Snipp16..250715.jul15
# 3213  http://www.rappler.com/nation/80272-floods-lan...
# 3214               http://www.myrepublica.com/news/2748
# 3215  http://www.indiatvnews.com/news/india/landslid...
#
#            article_publish_date  \
# 0                           NaN
# 1           2015-10-26 00:00:00
# 2           2015-03-10 00:00:00
# 3           2015-12-13 00:00:00
# 4           2016-04-25 00:00:00
# ...                         ...
# 3211  2013-07-12 15:10:08+00:00
# 3212                        NaN
# 3213  2015-01-09 09:16:11+00:00
# 3214                        NaN
# 3215  2014-11-07 16:45:00+05:30
#
#                                           article_title  \
# 0     Ratnagiri landslide: At least 12 people feared...
# 1     Earthquake Aftermath: 8 killed, 20 plus injure...
# 2                 Landslide destroys road in Montenegro
# 3     Northbound Interstate 5 reopens after mudslide...
# 4                        Dasheen money lost in mudslide
# ...                                                 ...
# 3211  Mudslides close Poudre Canyon highway at Ted’s...
# 3212  Mudslide destroys garage, jeep in Tamenglong :...
# 3213              Flood, landslides hit Surigao del Sur
# 3214                      Mudslide blocks Mechi Highway
# 3215               Landslide blocks Doda-Batote Highway
#
#                                            article_text  \
# 0     Reported By: | Edited By: |Source: ANI |Update...
# 1     Gilgit/Hunza/Skardu: At least eight people wer...
# 2     A huge landslide in Montenegro damaged more th...
# 3     A mudslide triggered by a storm moving through...
# 4     When Hubert Palmer left his home last Thursday...
# ...                                                 ...
# 3211  The Larimer County Sheriff’s Office reported a...
# 3212  Mudslide destroys garage, jeep in Tamenglong\n...
# 3213  Heavy, continuous rains cause flooding and lan...
# 3214  PAANCHTHAR, July 26: The Phidim-Raanke section...
# 3215  Follow us on landslide blocks doda batote high...
#
#                                                keywords  \
# 0     ['rescue', 'landslide', 'heavy', 'village', 't...
# 1     ['landslide', 'killed', 'plus', 'injured', 'hu...
# 2     ['metres', 'highway', 'landslide', 'destroys',...
# 3     ['winds', 'reopens', 'slams', 'mudslide', 'exp...
# 4     ['farmer', 'left', 'mudslide', 'family', 'hous...
# ...                                                 ...
# 3211  ['warning', 'highway', 'service', 'warned', 'w...
# 3212  ['users', 'headlines', 'jul15', 'garage', 'mud...
# 3213  ['flood', 'landslides', 'work', 'town', 'surig...
# 3214  ['temple', 'stated', 'highway', 'blocks', 'lan...
# 3215  ['vehicular', 'highway', 'blocks', 'landslide'...
#
#                                         article_summary category  \
# 0     Reported By: | Edited By: |Source: ANI |Update...      pos
# 1     Gilgit/Hunza/Skardu: At least eight people wer...      pos
# 2     A huge landslide in Montenegro damaged more th...      pos
# 3     A mudslide triggered by a storm moving through...      pos
# 4     When Hubert Palmer left his home last Thursday...      neg
# ...                                                 ...      ...
# 3211  The Larimer County Sheriff’s Office reported a...      pos
# 3212  Mudslide destroys garage, jeep in TamenglongSo...      pos
# 3213  Heavy, continuous rains cause flooding and lan...      pos
# 3214  PAANCHTHAR, July 26: The Phidim-Raanke section...      pos
# 3215  Follow us on landslide blocks doda batote high...      pos
#
#                                                    text lang  len_article
# 0     Ratnagiri landslide: At least 12 people feared...   en          132
# 1     Earthquake Aftermath: 8 killed, 20 plus injure...   en          460
# 2     Landslide destroys road in Montenegro\nA huge ...   en           28
# 3     Northbound Interstate 5 reopens after mudslide...   en          253
# 4     Dasheen money lost in mudslide\nWhen Hubert Pa...   en          236
# ...                                                 ...  ...          ...
# 3211  Mudslides close Poudre Canyon highway at Ted’s...   en          258
# 3212  Mudslide destroys garage, jeep in Tamenglong :...   en          185
# 3213  Flood, landslides hit Surigao del Sur\nHeavy, ...   en          282
# 3214  Mudslide blocks Mechi Highway\nPAANCHTHAR, Jul...   en          129
# 3215  Landslide blocks Doda-Batote Highway\nFollow u...   en          272
#
# [3216 rows x 19 columns]

# %%
nasa_df.query("id == 208")
# Out:
#     event_id                               location_description  \
# 52        79  village in Sichuan province's Garze region, He...
#
#    landslide_category landslide_trigger  fatality_count country_name  \
# 52          landslide              rain            18.0        China
#
#    admin_division_name gazetteer_closest_point   id  \
# 52               Gansu                    Xihe  208
#
#                                           source_link article_publish_date  \
# 52  http://news.bbc.co.uk/1/hi/world/asia-pacific/...  2007-05-26 07:25:32
#
#                        article_title  \
# 52  Western China landslides kill 21
#
#                                          article_text  \
# 52  Twelve people died and another 18 were injured...
#
#                                              keywords  \
# 52  ['mudslides', 'washed', 'landslides', 'rain', ...
#
#                                       article_summary category  \
# 52  Twelve people died and another 18 were injured...      pos
#
#                                                  text lang  len_article
# 52  Western China landslides kill 21\nTwelve peopl...   en          178

# %%
nasa_time_df = nasa_time_df.rename(columns={"contains correct time/date phrase" : "pos_sentence"})
nasa_time_df
# Out:
#           id         gold_date            extracted_dates  Unnamed: 0  \
# 0          0   2015-06-22 3:30        2015-06-22T14:30:00           0
# 1          0   2015-06-22 3:30        2015-06-22T14:30:00           1
# 2          0   2015-06-22 3:30        2015-06-22T14:30:00           2
# 3          0   2015-06-22 3:30        2015-06-22T14:30:00           3
# 4          0   2015-06-22 3:30        2015-06-22T14:30:00           4
# ...      ...               ...                        ...         ...
# 21422  35646  2016-07-25 23:00                 2016-07-26       26128
# 21423  35649  2014-11-06 18:00  2014-11-07 16:45:00+05:30       26129
# 21424  35649  2014-11-06 18:00  2014-11-07 16:45:00+05:30       26130
# 21425  35649  2014-11-06 18:00  2014-11-07 16:45:00+05:30       26131
# 21426  35649  2014-11-06 18:00  2014-11-07 16:45:00+05:30       26132
#
#                                                     text  \
# 0      Reported By: | Edited By: |Source: ANI |Update...
# 1      At least 12 people are feared to be buried und...
# 2      The landslide is said to have taken place at 3...
# 3      Ratnagiri (Maharashtra): Landslide occurred at...
# 4               pic.twitter.com/MOcmTxnAZX June 22, 2015
# ...                                                  ...
# 21422  Meanwhile, the Kanchanjunga Academy Higher Sec...
# 21423  Follow us on landslide blocks doda batote high...
# 21424  The highway was blocked after a landslide hit ...
# 21425  He said that the work to open the highway was ...
# 21426  “If there is no rain, we might throw the road ...
#
#                                 GPE  LOC            DATE             TIME  \
# 0                               NaN  NaN   Aug 04 , 2015     11:39 AM IST
# 1      Dabhol|Maharashtra|Ratnagiri  NaN             NaN              NaN
# 2                               NaN  NaN             NaN          3:30 am
# 3             Ratnagiri|Maharashtra  NaN             NaN  3 : 30 am today
# 4                               NaN  NaN  June 22 , 2015              NaN
# ...                             ...  ...             ...              ...
# 21422                      Phidim-1  NaN             NaN              NaN
# 21423                         Jammu  NaN             NaN              NaN
# 21424                          Doda  NaN             NaN     last evening
# 21425                           NaN  NaN           today          evening
# 21426                           NaN  NaN           today          evening
#
#        index                       normalized_date  \
# 0          0                                 None|
# 1          1                                   NaN
# 2          2                                   NaN
# 3          3                                   NaN
# 4          4  2015/06/22, 00:00-2015/06/22, 23:59|
# ...      ...                                   ...
# 21422  21422                                   NaN
# 21423  21423                                   NaN
# 21424  21424                                   NaN
# 21425  21425  2014/11/07, 00:00-2014/11/07, 23:59|
# 21426  21426  2014/11/07, 00:00-2014/11/07, 23:59|
#
#                             normalized_time pos_sentence  \
# 0      2015/06/22, 11:09-2015/06/22, 12:09|          neg
# 1                                       NaN          neg
# 2      2015/06/22, 03:00-2015/06/22, 04:00|          pos
# 3      2015/06/22, 03:00-2015/06/22, 04:00|          pos
# 4                                       NaN          pos
# ...                                     ...          ...
# 21422                                   NaN          neg
# 21423                                   NaN          neg
# 21424  2014/11/06, 18:00-2014/11/06, 22:00|          pos
# 21425  2014/11/07, 18:00-2014/11/07, 22:00|          neg
# 21426  2014/11/07, 18:00-2014/11/07, 22:00|          neg
#
#       date_phrase for normalization       normalized interval(from date)  \
# 0                               NaN                                  NaN
# 1                               NaN                                  NaN
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 4                    June 22 , 2015  2015/06/22, 00:00-2015/06/22, 23:59
# ...                             ...                                  ...
# 21422                           NaN                                  NaN
# 21423                           NaN                                  NaN
# 21424                           NaN                                  NaN
# 21425                           NaN                                  NaN
# 21426                           NaN                                  NaN
#
#       time_phrase for normalization       normalized interval(from time)
# 0                               NaN                                  NaN
# 1                               NaN                                  NaN
# 2                           3:30 am  2015/06/22, 03:00-2015/06/22, 04:00
# 3                   3 : 30 am today  2015/06/22, 03:00-2015/06/22, 04:00
# 4                               NaN                                  NaN
# ...                             ...                                  ...
# 21422                           NaN                                  NaN
# 21423                           NaN                                  NaN
# 21424                  last evening  2014/11/06, 18:00-2014/11/06, 22:00
# 21425                           NaN                                  NaN
# 21426                           NaN                                  NaN
#
# [21427 rows x 17 columns]

# %%
nasa_time_df.query("pos_sentence == 'pos'")
# Out:
#           id         gold_date            extracted_dates  Unnamed: 0  \
# 2          0   2015-06-22 3:30        2015-06-22T14:30:00           2
# 3          0   2015-06-22 3:30        2015-06-22T14:30:00           3
# 4          0   2015-06-22 3:30        2015-06-22T14:30:00           4
# 6          0   2015-06-22 3:30        2015-06-22T14:30:00           6
# 7          1   2015-10-26 0:00        2015-10-26 00:00:00           7
# ...      ...               ...                        ...         ...
# 21389  35598  2015-07-04 18:00        2015-07-05T12:37:00       26095
# 21391  35606  2014-06-30 15:00        2014-07-01 00:00:00       26097
# 21402  35610  2013-07-12 16:00  2013-07-12 15:10:08+00:00       26108
# 21420  35646  2016-07-25 23:00                 2016-07-26       26126
# 21424  35649  2014-11-06 18:00  2014-11-07 16:45:00+05:30       26130
#
#                                                     text  \
# 2      The landslide is said to have taken place at 3...
# 3      Ratnagiri (Maharashtra): Landslide occurred at...
# 4               pic.twitter.com/MOcmTxnAZX June 22, 2015
# 6      pic.twitter.com/a5mMtI2hwB — ANI (@ANI_news) J...
# 7      Gilgit/Hunza/Skardu: At least eight people wer...
# ...                                                  ...
# 21389  GTA chief Bimal Gurung yesterday called up Wes...
# 21391  GENERAL SANTOS CITY (MindaNews/01 July) — An u...
# 21402  About 4 p.m., the Sheriff’s Office also report...
# 21420  PAANCHTHAR, July 26: The Phidim-Raanke section...
# 21424  The highway was blocked after a landslide hit ...
#
#                                                  GPE  LOC            DATE  \
# 2                                                NaN  NaN             NaN
# 3                              Ratnagiri|Maharashtra  NaN             NaN
# 4                                                NaN  NaN  June 22 , 2015
# 6                                                NaN  NaN  June 22 , 2015
# 7                                   Gilgit-Baltistan  NaN           today
# ...                                              ...  ...             ...
# 21389                                    West Bengal  NaN       yesterday
# 21391  SANTOS CITY|MindaNews|Tampakan|South Cotabato  NaN          Monday
# 21402                                       Colorado  NaN             NaN
# 21420       PAANCHTHAR|Phidim-Raanke|Samdin|Phidim-2  NaN         July 26
# 21424                                           Doda  NaN             NaN
#
#                      TIME  index                       normalized_date  \
# 2                 3:30 am      2                                   NaN
# 3         3 : 30 am today      3                                   NaN
# 4                     NaN      4  2015/06/22, 00:00-2015/06/22, 23:59|
# 6      Earlier in the day      6  2015/06/22, 00:00-2015/06/22, 23:59|
# 7                     NaN      7  2015/10/26, 00:00-2015/10/26, 23:59|
# ...                   ...    ...                                   ...
# 21389                 NaN  21389  2015/07/04, 00:00-2015/07/04, 23:59|
# 21391           afternoon  21391  2014/06/30, 00:00-2014/06/30, 23:59|
# 21402        About 4 p.m.  21402                                   NaN
# 21420          last night  21420  2015/07/26, 00:00-2015/07/26, 23:59|
# 21424        last evening  21424                                   NaN
#
#                             normalized_time pos_sentence  \
# 2      2015/06/22, 03:00-2015/06/22, 04:00|          pos
# 3      2015/06/22, 03:00-2015/06/22, 04:00|          pos
# 4                                       NaN          pos
# 6                                     None|          pos
# 7                                       NaN          pos
# ...                                     ...          ...
# 21389                                   NaN          pos
# 21391  2014/07/01, 12:00-2014/07/01, 17:00|          pos
# 21402  2013/07/12, 15:30-2013/07/12, 16:30|          pos
# 21420  2016/07/25, 23:00-2016/07/26, 04:00|          pos
# 21424  2014/11/06, 18:00-2014/11/06, 22:00|          pos
#
#       date_phrase for normalization       normalized interval(from date)  \
# 2                               NaN                                  NaN
# 3                               NaN                                  NaN
# 4                    June 22 , 2015  2015/06/22, 00:00-2015/06/22, 23:59
# 6                    June 22 , 2015  2015/06/22, 00:00-2015/06/22, 23:59
# 7                             today  2015/10/26, 00:00-2015/10/26, 23:59
# ...                             ...                                  ...
# 21389                     yesterday  2015/07/04, 00:00-2015/07/04, 23:59
# 21391                        Monday  2014/06/30, 00:00-2014/06/30, 23:59
# 21402                           NaN                                  NaN
# 21420                           NaN                                  NaN
# 21424                           NaN                                  NaN
#
#       time_phrase for normalization       normalized interval(from time)
# 2                           3:30 am  2015/06/22, 03:00-2015/06/22, 04:00
# 3                   3 : 30 am today  2015/06/22, 03:00-2015/06/22, 04:00
# 4                               NaN                                  NaN
# 6                               NaN                                  NaN
# 7                               NaN                                  NaN
# ...                             ...                                  ...
# 21389                           NaN                                  NaN
# 21391                           NaN                                  NaN
# 21402                  About 4 p.m.  2013/07/12, 15:30-2013/07/12, 16:30
# 21420                    last night  2016/07/25, 23:00-2016/07/26, 04:00
# 21424                  last evening  2014/11/06, 18:00-2014/11/06, 22:00
#
# [2326 rows x 17 columns]

# %%
nasa_loc_df
# Out:
#           id                                               text  \
# 0          0  Reported By: | Edited By: |Source: ANI |Update...
# 1          0  At least 12 people are feared to be buried und...
# 2          0  The landslide is said to have taken place at 3...
# 3          0  Ratnagiri (Maharashtra): Landslide occurred at...
# 4          0           pic.twitter.com/MOcmTxnAZX June 22, 2015
# ...      ...                                                ...
# 26128  35646  Meanwhile, the Kanchanjunga Academy Higher Sec...
# 26129  35649  Follow us on landslide blocks doda batote high...
# 26130  35649  The highway was blocked after a landslide hit ...
# 26131  35649  He said that the work to open the highway was ...
# 26132  35649  “If there is no rain, we might throw the road ...
#
#                                     location_description  \
# 0      Dabhol village of Maharashtra's Ratnagiri dist...
# 1      Dabhol village of Maharashtra's Ratnagiri dist...
# 2      Dabhol village of Maharashtra's Ratnagiri dist...
# 3      Dabhol village of Maharashtra's Ratnagiri dist...
# 4      Dabhol village of Maharashtra's Ratnagiri dist...
# ...                                                  ...
# 26128  Phidim-Raanke section of the Mechi Highway at ...
# 26129           Chakwa bridge, 9 kilomters short of Doda
# 26130           Chakwa bridge, 9 kilomters short of Doda
# 26131           Chakwa bridge, 9 kilomters short of Doda
# 26132           Chakwa bridge, 9 kilomters short of Doda
#
#                            locations                       dates pos_sentence  \
# 0                                  |  Aug 04 , 2015|11:39 AM IST           No
# 1      Dabhol|Maharashtra|Ratnagiri|                           |          Yes
# 2                                  |                    |3:30 am           No
# 3             Ratnagiri|Maharashtra|            |3 : 30 am today           No
# 4                                  |             June 22 , 2015|           No
# ...                              ...                         ...          ...
# 26128                      Phidim-1|                           |           No
# 26129                         Jammu|                           |           No
# 26130                          Doda|               |last evening          Yes
# 26131                              |               today|evening           No
# 26132                              |               today|evening           No
#
#        number_of_pos_sent  contain_pos_sent
# 0                       1              True
# 1                       1              True
# 2                       1              True
# 3                       1              True
# 4                       1              True
# ...                   ...               ...
# 26128                   1              True
# 26129                   1              True
# 26130                   1              True
# 26131                   1              True
# 26132                   1              True
#
# [26133 rows x 8 columns]

# %% [markdown]
# ## Get best locations

# %%
def get_distance(p1, p2):
    """Get the geographical distance between two points"""
    if p1 and p2:
        return round(geopy.distance.geodesic(p1, p2).km, 3)
    else:
        return None

def get_smallest_region_idx(locs):
    """
    Parameters
    ----------
    locs : list of dictionary
        a list of dictionary containing latitude, longitude, 
        northeast point, southwest point for all the location 
        entities in the positive sentence
    
    Returns
    ----------
        an integer indicating the index of the location entity 
        that has the smallest region
    """
    dists = [get_distance(loc['northeast'], loc['southwest']) for loc in locs]
    return dists.index(min(dists))

def filter_location_by_size(locs):
    geolocs = []
    for loc in locs:
        geocoded = geocoder.arcgis(loc).json
        if geocoded:
            geoloc = geocoded['bbox']
            geoloc['lat'], geoloc['lng'] = geocoded['lat'], geocoded['lng']
            geolocs.append(geoloc)

    if geolocs:
        j = get_smallest_region_idx(geolocs)
        return locs[j]
    else:
        return ""

# %%
def extract_location(locations, location_description):
    matching_locations = []

    if not type(locations) == list or not type(location_description) == str:
        return []

    for location in locations:
        if location and location in location_description:
            matching_locations.append(location)
    return matching_locations


location_tags = []
for id in tqdm(nasa_df["id"].to_numpy()):
    location_rows = nasa_loc_df.query(f"id == {id} and pos_sentence == 'Yes'")

    location = []
    for location_row_id in range(location_rows.shape[0]):
        location.extend(
            extract_location(
                location_rows.iloc[location_row_id]["locations"].split("|"),
                location_rows.iloc[location_row_id]["location_description"],
            )
        )
        location = list(
            set(
                [
                    loc
                    for loc in location
                    if not any([loc in l for l in location if loc != l])
                ]
            )
        )

    nasa_row = nasa_df.query(f"id == {id}").iloc[0]
    if (
        type(nasa_row["gazetteer_closest_point"]) == str
        and nasa_row["gazetteer_closest_point"] in nasa_row["text"]
    ):
        location.append(nasa_row["gazetteer_closest_point"])
    elif (
        type(nasa_row["admin_division_name"]) == str
        and nasa_row["admin_division_name"] in nasa_row["text"]
    ):
        location.append(nasa_row["admin_division_name"])
    if (
        type(nasa_row["country_name"]) == str
        and nasa_row["country_name"] in nasa_row["text"]
    ):
        location.append(nasa_row["country_name"])

    if not location or len(location) == 0:
        best_location = ""
    elif len(location) == 1:
        best_location = location[0]
    elif len(location) > 1:
        best_location = filter_location_by_size(location)

    location_tags.append(best_location)
# Out:
# 100%|██████████| 3216/3216 [55:51<00:00,  1.04s/it]

# %% [markdown]
# ## Get best dates

# %%
date_tags = []
time_tags = []
weekdays = ["monday", "tuesday", "wednesday", "thursday", "friday", "saturday", "sunday"]
for id in tqdm(nasa_df["id"].to_numpy()):
    date_time = nasa_time_df.query(f"id == {id} and pos_sentence == 'pos'")
    date = list(set(date_time["date_phrase for normalization"].dropna().to_numpy()))
    time = list(set(date_time["time_phrase for normalization"].dropna().to_numpy()))

    if not date:
        best_date = ""
    elif len(date) == 1:
        best_date = date[0]
    elif len(date) > 1:
        for d in date:
            if d.lower() == "today":
                best_date = d
                break
            if any(c.isdigit() for c in d):
                best_date = d
                break
            if any(d.lower() == w for w in weekdays):
                best_date = d
                break
        best_date = date[0]

    if not time:
        best_time = ""
    elif len(time) == 1:
        best_time = time[0]
    elif len(time) > 1:
        best_time = time[0]

    date_tags.append(best_date)
    time_tags.append(best_time)
# Out:
# 100%|██████████| 3216/3216 [00:06<00:00, 474.07it/s]

# %% [markdown]
# ## Get casualities

# %%
cas_tags = []
for id in tqdm(nasa_df["id"].to_numpy()):
    cas_count = nasa_df.query(f"id == {id}")["fatality_count"].iloc[0]
    text = nasa_df.query(f"id == {id}")["text"].iloc[0]

    if cas_count == cas_count and cas_count > 0:
        if " " + str(int(cas_count)) + " " in text:
            cas_tags.append(str(int(cas_count)))
        elif p.number_to_words(int(cas_count)) in text:
            cas_tags.append(p.number_to_words(int(cas_count)))
        else:
            cas_tags.append("")
    else:
        cas_tags.append("")
# Out:
# 100%|██████████| 3216/3216 [00:12<00:00, 255.20it/s]

# %%
p.number_to_words(8.0)
# Out:
# 'eight point zero'

# %% [markdown]
# ## Output

# %%
cas_tags
# Out:
# ['12',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '7',
#  '',
#  '4',
#  '',
#  '',
#  '',
#  '2',
#  '',
#  '',
#  'two',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '6',
#  '',
#  '',
#  '',
#  '18',
#  '',
#  '',
#  'three',
#  '',
#  '',
#  'one',
#  '',
#  'one',
#  'one',
#  '',
#  '6',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'seven',
#  '',
#  'four',
#  '',
#  '',
#  '',
#  '',
#  'three',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'two',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '27',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '11',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '3',
#  '',
#  '',
#  '',
#  '',
#  'three',
#  'five',
#  'one',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '',
#  'five',
#  '',
#  'five',
#  '3',
#  '',
#  '19',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'five',
#  'one',
#  '',
#  'five',
#  '',
#  '4',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '7',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  '5',
#  '',
#  '',
#  '',
#  'eight',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  'four',
#  '',
#  'two',
#  'two',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'five',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'two',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'three',
#  '',
#  '',
#  '',
#  '',
#  'three',
#  '',
#  'one',
#  '',
#  '',
#  'four',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '2',
#  '4',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'five',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'two',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'three',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'two',
#  '',
#  '20',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'two',
#  'five',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'two',
#  'one',
#  '',
#  '',
#  'seven',
#  'one',
#  '',
#  'five',
#  'four',
#  'seven',
#  '',
#  '',
#  '',
#  'four',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'five',
#  '',
#  'one',
#  '',
#  'five',
#  'six',
#  '',
#  '',
#  '',
#  '',
#  'three',
#  '',
#  '',
#  '',
#  '12',
#  '',
#  '',
#  '',
#  'two',
#  '3',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  'eight',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'three',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '5',
#  '17',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '18',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'three',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'seven',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'five',
#  '',
#  'four',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'three',
#  '',
#  '',
#  'one',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  'nine',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '6',
#  '',
#  '',
#  '',
#  '',
#  '3',
#  '',
#  '',
#  'one',
#  '54',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '4',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'two',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '18',
#  '10',
#  'two',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'three',
#  '',
#  '',
#  'seven',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'five',
#  '',
#  '12',
#  '',
#  '8',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'four',
#  '',
#  '',
#  '',
#  'six',
#  '',
#  'two',
#  '',
#  '',
#  'three',
#  'two',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'two',
#  '',
#  '',
#  '',
#  '',
#  '1',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2',
#  '',
#  'two',
#  '',
#  '',
#  '',
#  'four',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  'two',
#  '',
#  '10',
#  '',
#  '',
#  '',
#  'two',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2',
#  '',
#  'five',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  '6',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  'ten',
#  '',
#  '',
#  '',
#  'two',
#  '',
#  '',
#  '',
#  '',
#  'two',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'six',
#  '',
#  '',
#  '',
#  '12',
#  'one',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'two',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '7',
#  '',
#  '',
#  '',
#  '11',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '5',
#  'six',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'three',
#  '',
#  '',
#  'three',
#  '',
#  'four',
#  '',
#  '2',
#  '',
#  '',
#  'one',
#  '',
#  '18',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  '',
#  'three',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'six',
#  '',
#  '',
#  '105',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '46',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'four',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'five',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'five',
#  '',
#  '',
#  'one',
#  '',
#  '',
#  'two',
#  '',
#  '',
#  '10',
#  '',
#  '',
#  '',
#  '',
#  'four',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '41',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'seven',
#  '',
#  '',
#  '',
#  '24',
#  '',
#  '',
#  'two',
#  '',
#  '',
#  ...]

# %%
len([c for c in cas_tags if c != ""])
# Out:
# 584

# %%
date_tags
# Out:
# ['June 22 , 2015',
#  'today',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'today',
#  '',
#  '',
#  '',
#  'Wednesday',
#  '',
#  '',
#  'Tuesday',
#  '',
#  '',
#  'Sunday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Thursday',
#  '',
#  '',
#  'yesterday',
#  '',
#  '',
#  '',
#  'Thursday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sunday',
#  'Friday',
#  '',
#  '',
#  '',
#  'Last week',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Friday',
#  '',
#  '',
#  'July 15 , 2015',
#  '',
#  '',
#  '',
#  '',
#  'this month',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Thursday',
#  'August 21 , 2014',
#  '',
#  '',
#  'Sunday',
#  '',
#  'this week',
#  '',
#  '',
#  'last week',
#  'Friday',
#  'October 11th , 2016',
#  'Saturday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'a week',
#  '',
#  '',
#  'Thursday',
#  'February 6 , 2017',
#  'the past one week',
#  '',
#  '',
#  '',
#  '',
#  'Last week',
#  '',
#  'Monday',
#  'winter',
#  '',
#  'Saturday',
#  '',
#  '',
#  'Saturday',
#  '',
#  '',
#  'Sunday',
#  '',
#  'Wednesday',
#  'Today',
#  'October 29',
#  '',
#  '',
#  '',
#  '',
#  'Friday',
#  '',
#  '',
#  'today',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Aug. 2',
#  'Monday',
#  'the winter of 2008-09',
#  '',
#  'today',
#  '',
#  '',
#  'yesterday',
#  'yesterday',
#  'May 12 to May 16',
#  '',
#  'the weekend',
#  '',
#  '',
#  'Sunday',
#  '',
#  '',
#  '',
#  'Tuesday',
#  'Saturday',
#  'Tuesday',
#  '',
#  'yesterday',
#  '',
#  'Friday',
#  '',
#  '',
#  'Thursday',
#  '',
#  'October 19 , 2015',
#  'a week',
#  'Monday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Wednesday',
#  'Wednesday',
#  'Sunday',
#  'Saturday',
#  '',
#  'today',
#  '',
#  '',
#  'October 12',
#  '',
#  'yesterday',
#  '',
#  '',
#  '',
#  'today',
#  '',
#  '',
#  '',
#  '',
#  'Sunday',
#  'Sept. 12',
#  '',
#  'last month',
#  'today',
#  '',
#  'February 10 , 2017',
#  '',
#  '',
#  'Feb. 10',
#  '',
#  '',
#  '',
#  'yesterday',
#  'Wednesday',
#  '',
#  'Sunday through Tuesday',
#  '09 April',
#  'Friday , May 5',
#  '',
#  '',
#  'December 18 , 2017',
#  '',
#  '',
#  '',
#  '',
#  'Saturday',
#  '',
#  '',
#  'summer',
#  '',
#  'Wednesday',
#  '',
#  '',
#  '',
#  '',
#  'July 18',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Thursday',
#  '',
#  '',
#  '',
#  'winter',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sunday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'weekend',
#  '',
#  'Wednesday',
#  '',
#  'Friday',
#  '',
#  '',
#  '',
#  'earlier this week',
#  '',
#  '',
#  'August 7 )',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Thursday',
#  '',
#  'Monday',
#  '',
#  'Tuesday',
#  'yesterday',
#  'yesterday',
#  'July 20 , 2016',
#  'the spring',
#  'Monday',
#  'Thursday',
#  'Tuesday',
#  'today',
#  '',
#  'today',
#  'Sunday',
#  'Thursday',
#  '',
#  '',
#  '',
#  'today',
#  '',
#  '',
#  'Sunday',
#  'the entire month of May',
#  '',
#  '',
#  '',
#  'August 11 , 2018',
#  '',
#  '',
#  'August 13 , 2018',
#  '',
#  '',
#  'earlier in the week',
#  '',
#  '',
#  '30 July',
#  'Saturday',
#  'Sunday',
#  '',
#  '',
#  '',
#  '',
#  'Tuesday',
#  '',
#  'June 27',
#  '',
#  '',
#  'Sunday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Thursday',
#  'Friday',
#  'Sunday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'earlier this month',
#  'early yesterday',
#  '',
#  'early this week',
#  '',
#  '',
#  '',
#  'yesterday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'yesterday',
#  'less than a week',
#  '',
#  '',
#  'all day today',
#  '',
#  '',
#  'Monday ( 17 / 04 )',
#  '',
#  'today',
#  'Friday',
#  '',
#  '',
#  '',
#  'earlier in the week',
#  'Monday',
#  '',
#  '',
#  '',
#  'Saturday',
#  '',
#  '',
#  'Monday',
#  'May 27',
#  'Tuesday',
#  'this week',
#  'September 25',
#  'Wednesday',
#  '',
#  '',
#  'the driest month of the dry season',
#  'August 30',
#  '',
#  '',
#  '',
#  '',
#  'Monday',
#  'Sunday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'today',
#  'August 8',
#  'this week',
#  'yesterday',
#  '',
#  '',
#  '',
#  'the past one week',
#  '',
#  'the end of the week',
#  'Thursday , June 23 , 2016',
#  '',
#  '',
#  'Wednesday',
#  'Tuesday',
#  '',
#  'Thursday',
#  '',
#  'the summer',
#  '',
#  'Saturday',
#  '',
#  'the week',
#  '',
#  '',
#  'spring',
#  'the month',
#  '',
#  '',
#  'earlier this week',
#  'the end of the month',
#  '',
#  'Monday',
#  'yesterday',
#  'Friday',
#  '',
#  'Monday',
#  '',
#  '',
#  '',
#  'Wednesday',
#  'the last one month',
#  '',
#  '',
#  '',
#  'Thursday',
#  '',
#  '',
#  '',
#  'today',
#  '',
#  '',
#  'Wednesday',
#  '',
#  '',
#  'July 25th',
#  '',
#  'yesterday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'spring',
#  '',
#  '',
#  'autumn',
#  '',
#  '',
#  'Saturday',
#  '',
#  '',
#  '',
#  '',
#  'this week',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sunday',
#  'Tuesday , June 13',
#  '',
#  '',
#  '',
#  'today',
#  '',
#  'Monday',
#  'this weekend',
#  'Thursday',
#  'March 12',
#  '',
#  'August 6 , 2007',
#  '',
#  '',
#  'today',
#  '',
#  '',
#  'Winter',
#  'Sunday',
#  '',
#  'the winter of 1952',
#  '',
#  '',
#  'Friday',
#  'Tuesday',
#  '',
#  'Monday',
#  '',
#  '',
#  '',
#  'Sunday',
#  '',
#  'the month of July',
#  '',
#  'August 20 , 2008',
#  '',
#  '',
#  'Friday',
#  'each summer',
#  'October 3',
#  '',
#  '',
#  'July 16',
#  'December 29',
#  'August 12',
#  '',
#  '',
#  '',
#  '',
#  'Thursday',
#  '',
#  '',
#  'Thursday',
#  '',
#  '',
#  'today',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Tuesday',
#  '',
#  'Thursday',
#  '',
#  'today',
#  '',
#  '',
#  '',
#  '',
#  'Wednesday',
#  '',
#  '',
#  'between June 15 and 17',
#  'July 28',
#  '',
#  '',
#  '',
#  'yesterday',
#  'Friday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Wednesday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sunday',
#  'the weekend',
#  '',
#  '',
#  'all week',
#  'Friday',
#  '',
#  '',
#  'today',
#  '',
#  'Monday',
#  'more than a month',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Thursday',
#  '',
#  'December 6 , 2018',
#  '',
#  '',
#  '',
#  'yesterday',
#  '',
#  '',
#  '',
#  '',
#  'September last year',
#  'August 9',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '15th to 17th August',
#  '',
#  '',
#  '',
#  '',
#  'the start of the month',
#  'Sunday',
#  '',
#  '',
#  '',
#  '7 / 21 / 16',
#  '',
#  '',
#  'Tuesday',
#  '',
#  '',
#  '',
#  '',
#  'earlier in the week',
#  'earlier this week',
#  '',
#  'today',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Thursday',
#  'Saturday',
#  '',
#  'Wednesday',
#  'Tuesday',
#  '',
#  '',
#  '',
#  'Monday',
#  'the weekend',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'a weekend',
#  'Tuesday',
#  'Thursday',
#  '',
#  'Monday',
#  'Sunday',
#  'the early spring',
#  '',
#  'Sunday',
#  'Sunday',
#  '',
#  '',
#  'September 14',
#  'Monday',
#  'Sunday',
#  '',
#  '',
#  'Jan. 9',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'winter',
#  'today',
#  '',
#  '',
#  '',
#  '',
#  'Sunday',
#  'Friday',
#  'Friday',
#  '',
#  '',
#  '',
#  'August 29',
#  'December 13 , 2018',
#  '',
#  'Friday',
#  '',
#  'yesterday',
#  'last weekend',
#  'early this week',
#  'September 19',
#  '',
#  '',
#  '',
#  '',
#  'Thursday',
#  '',
#  '',
#  'Saturday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Jan. 7',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'this week',
#  'last week',
#  'Sunday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Saturday',
#  'Thursday',
#  'this summer',
#  'this month',
#  '',
#  '',
#  '',
#  'today',
#  '',
#  '',
#  'October 18 , 2010',
#  '',
#  '',
#  'over a week',
#  'yesterday',
#  'Sept 17 , 2011',
#  'Tuesday',
#  '',
#  '',
#  '',
#  '',
#  'Sunday',
#  '',
#  '',
#  '',
#  'June 30',
#  '',
#  '',
#  '',
#  'Wednesday',
#  '',
#  '',
#  '',
#  'Thursday',
#  'Saturday',
#  'Saturday',
#  'today',
#  '',
#  '',
#  'Friday',
#  'today',
#  '',
#  '',
#  'Sunday',
#  '',
#  '',
#  '',
#  'yesterday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Saturday , March 11 , 2017',
#  'yesterday',
#  '',
#  'between Thursday and Friday',
#  'earlier this month',
#  'today',
#  '',
#  '',
#  'yesterday',
#  'Wednesday',
#  'Friday',
#  'November 21',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Wednesday',
#  '',
#  'November 29 , 2018',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'July 22',
#  'Wednesday',
#  '',
#  '',
#  '',
#  'Saturday',
#  'Monday',
#  '',
#  '',
#  'Tuesday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'today',
#  '',
#  '',
#  'today',
#  'Monday',
#  'May 16 , 2016',
#  'today',
#  '',
#  'today',
#  '',
#  'Dec 7 , 2015',
#  '',
#  '',
#  '',
#  'November 20 , 2007',
#  '',
#  '',
#  'the week',
#  '',
#  '',
#  'June one',
#  'Tuesday',
#  '',
#  'yesterday',
#  'Sunday',
#  '',
#  'last Saturday',
#  'Friday',
#  'Saturday',
#  'Monday',
#  '',
#  'May 11',
#  '',
#  'Friday',
#  '',
#  '25th July',
#  '',
#  'Sunday',
#  '',
#  '',
#  '',
#  'Saturday',
#  '',
#  'today',
#  '',
#  'Thursday',
#  'June 19 2015',
#  'Tuesday',
#  'Sunday',
#  'Friday',
#  '',
#  '2012-06-10 23:18',
#  '',
#  '',
#  'Nov. 11',
#  'Thursday',
#  'Saturday',
#  '',
#  '',
#  '',
#  'Monday',
#  '',
#  'Tuesday',
#  '',
#  '',
#  '',
#  'the week',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Friday',
#  'Thursday',
#  'April 21st',
#  'winter',
#  '',
#  'today',
#  'Sunday',
#  'Friday',
#  'all winter',
#  '',
#  'today',
#  '',
#  'Tuesday',
#  'August 15 to 19',
#  'Tuesday',
#  '',
#  'Tuesday',
#  '',
#  'Friday',
#  '',
#  'Wednesday',
#  '',
#  '',
#  'Saturday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'today',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'last Sunday morning',
#  '',
#  'October 14 2016',
#  'Aug. 9 , 2015',
#  '',
#  '',
#  'almost one month',
#  'October 13',
#  'this month',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'the end of September',
#  '',
#  'Thursday',
#  '',
#  '',
#  'Sunday',
#  'weekend',
#  'Feb. 6',
#  '',
#  '',
#  '',
#  'June 9',
#  'today',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Saturday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Saturday',
#  'last week',
#  '',
#  'up to a month',
#  '',
#  '',
#  'Friday',
#  '',
#  '',
#  '',
#  '',
#  ...]

# %%
time_tags
# Out:
# ['3:30 am',
#  '',
#  '',
#  'evening',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'early Saturday morning',
#  'this morning',
#  '5 am today',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '12.15pm yesterday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'earlier this morning',
#  '',
#  '',
#  '',
#  '',
#  'Tuesday afternoon',
#  '',
#  '',
#  '',
#  '',
#  'around 9:30 p.m. on August 21',
#  '',
#  '6 p.m . Tuesday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'about 10 a.m.',
#  '',
#  '',
#  '',
#  'tonight',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'the morning',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'the morning',
#  '',
#  'late Monday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'early yesterday',
#  '',
#  '',
#  '',
#  'the night',
#  '',
#  '',
#  '',
#  'morning',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'around 12:30 a.m. on October 19 , 2015',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1:47 p.m . Wednesday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'early Monday morning',
#  '',
#  '',
#  '',
#  '',
#  'morning',
#  '',
#  '',
#  '',
#  '',
#  '1 p.m.',
#  '',
#  'about 3 p.m.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '10:00 am',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '4:30 a.m.',
#  '',
#  'evening',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'afternoon',
#  '',
#  '',
#  'night',
#  '',
#  '',
#  '',
#  'around 4:30 a.m. of September 22',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Sunday night',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'the morning',
#  'Monday afternoon',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Monday night',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '4:43 p.m.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '1 p.m . June 27',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '2 a.m.',
#  'around 12.10am this morning',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'the later morning hours',
#  'early yesterday',
#  '',
#  '',
#  '',
#  '',
#  '4 p.m.',
#  'Monday night',
#  '',
#  'late last night',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '9 a.m. yesterday',
#  'late Wednesday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'around 2 am this morning',
#  '',
#  'morning',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'early Tuesday',
#  '',
#  '12:30 on May 5th',
#  '',
#  '5 a.m.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'morning',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'morning',
#  '',
#  '',
#  '',
#  'Tuesday night',
#  'early in the morning',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'last night',
#  '',
#  '',
#  '',
#  'Tuesday night',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'afternoon',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Wednesday night',
#  '',
#  '',
#  '',
#  '',
#  '9 am',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'evening',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Tuesday night',
#  '',
#  'morning',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'morning',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'about 12:10 p.m.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '10:30 am Sunday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'about 6 p.m . Monday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'around 11:30 a.m.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'late Tuesday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'morning',
#  '',
#  'morning',
#  '',
#  '',
#  '',
#  '9am Saturday',
#  '',
#  'Tuesday morning',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Earlier today',
#  'Wednesday night',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'about 1:30 a.m.',
#  '',
#  '10 am',
#  '',
#  '',
#  '',
#  'Tuesday night',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Thursday night',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '5:15 in the morning',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '10 p.m. last night',
#  '',
#  '2:00 am',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'morning',
#  '',
#  '',
#  '',
#  '5:06 a.m.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'just after 2pm today',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '7 a.m . Thursday',
#  '',
#  '',
#  '',
#  'Wednesday night',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'about 2 pm',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'this morning',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Saturday evening',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'late Saturday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'the night',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'afternoon',
#  '',
#  '11.40 last night',
#  '',
#  'evening',
#  '',
#  'tonight',
#  '5 am',
#  '',
#  'just before noon',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'around 8:30 a.m.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'late Sunday afternoon',
#  '',
#  '',
#  '',
#  'Last Saturday night',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'early Sunday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '4:40 p.m.',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'early afternoon',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'early today morning',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'early yesterday',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'afternoon',
#  '',
#  '',
#  'Wednesday night',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'morning',
#  '',
#  '',
#  '',
#  ...]

# %%
location_tags
# Out:
# ['Dabhol',
#  'Ghizar District',
#  'Montenegro',
#  'Fort Tejon',
#  'Portland',
#  'Keremeos',
#  '',
#  'Jombang',
#  'Elk City',
#  'Sichuan Province',
#  'Nova Friburgo',
#  'Narayangadh-Muglin',
#  '',
#  'Rizal',
#  'Laguna Beach',
#  'Pokhara-Baglung-Jomsom',
#  'Villa Hidalgo Yalalag',
#  'American Fork Canyon',
#  'Oregon',
#  'Nivsar',
#  'Kabandungan',
#  'Salyan',
#  'Guimaras',
#  '',
#  '',
#  'Alpine',
#  'Palakkayam',
#  'Varna',
#  'Baringo',
#  'Billawar tehsil',
#  'Barangay Cantao-an',
#  'Lianyuan',
#  'Philippines',
#  'Gundogdu',
#  'Contin',
#  'Mukilteo',
#  'Girard',
#  'Beluru-Lapok',
#  'Edmonds',
#  'Benguet',
#  'Threlkeld',
#  'Nelson',
#  'Tawang',
#  'St. Mary',
#  'United States',
#  'Asheville',
#  'Skipton',
#  'Roca Tarpeya',
#  'Florencia',
#  'Liverpool',
#  'Sumilao',
#  'Kawnpui',
#  'Garze',
#  '',
#  'Gilman Springs',
#  'Seppa',
#  'Vancouver',
#  'VA',
#  'Ferozeguda',
#  '',
#  'El Vigía',
#  'LoC',
#  'Cincinnati',
#  'Narayanghat',
#  'Ciregol',
#  'Malang',
#  'Kalinga',
#  'Baguio',
#  'Sharon Springs',
#  '',
#  'Barangay Sinuda',
#  'Armenia',
#  'Portland',
#  'Shaoguan',
#  'Keelung',
#  'Manipur',
#  'Nuevo Arenal',
#  '',
#  'Bunar valley',
#  'Castleton',
#  'Baku',
#  'Edmonds',
#  '',
#  'Guandao township',
#  'California',
#  'Putnam County',
#  'Scotts Valley',
#  'Portland',
#  'Bukit Antarabangsa',
#  'Carigara',
#  'Glenbrook',
#  'Itanagar',
#  'Woodland',
#  'Eden',
#  'Kishtwar',
#  'Assam',
#  'South Prairie Road East',
#  'Greenwood',
#  'California',
#  'California',
#  'New Richmond',
#  'Ponorogo',
#  'Penang',
#  'Washington',
#  'East Gate Landslide',
#  '',
#  'Wonosobo',
#  'Campbell River',
#  'Gellibrand',
#  'Kerala',
#  'Jammu',
#  'Milin',
#  'Lawrence County',
#  'Quakertown',
#  'Shanxi Province',
#  'Colima',
#  'Taplejung',
#  'Yagodka',
#  'Udupi',
#  'Dungi',
#  'Vilnius',
#  'Syangja',
#  'Mauban',
#  'Mexico City',
#  'California',
#  'China',
#  'Stevens Pass',
#  'Randle',
#  'Chhindwara',
#  'Rakha Jaganoo',
#  'Mangwaneni',
#  'Mountain Province',
#  'Casuntingan',
#  'Hsinchu County',
#  'San José',
#  'Darjeeling',
#  'North Phyongan Province',
#  'Patseu',
#  'Lohit',
#  'Mt. Baldy',
#  'Jacarepagua',
#  'Kallarakodi',
#  'Bhutan',
#  'Haiti',
#  'Naran',
#  'Mersa',
#  'Kota Agung',
#  'Mandi',
#  'North Salt Lake',
#  'Eagle Creek',
#  'Quin',
#  'Blagoevgrad',
#  'San Anselmo',
#  'Papua',
#  'Benguet',
#  'Sør-Trøndelag',
#  'Talisay City',
#  'Ikou-Gangpijang',
#  'Western Cape',
#  'Placerville',
#  'Mtskheta',
#  'Manipur',
#  'Badrinath',
#  'Anhui',
#  'Tanjung Sani',
#  'Pulabato',
#  'WV',
#  'Alsea',
#  'Basilisa',
#  'Jasaan',
#  'Madula panchayat',
#  'Trieste',
#  'Alajuela',
#  'Lumbayao village',
#  '',
#  'Nanping',
#  'Lillooet',
#  'Costa Rica',
#  'Kerala',
#  'Bulanao',
#  'Hillsborough',
#  'Anchor Bay',
#  'Boise',
#  'Dindoshi',
#  'Ohio',
#  'Hana',
#  'Kundiawa',
#  'Los Gatos',
#  'San Rafael',
#  'Malivo',
#  'South Yuba Canal',
#  'Ben Lomond',
#  'Lytle Creek',
#  'Grand Canyon',
#  'Bikita',
#  'Jammu',
#  'Solan',
#  'Semarang',
#  'Indonesia',
#  'Anglemont',
#  'Lombok',
#  '',
#  'Java',
#  'Hawaii',
#  'Great Western',
#  'Mocollop',
#  'Jalan Buah Jambu',
#  'Bomdila',
#  'Gang Ranch',
#  'Narayangarh',
#  'Aksu',
#  'Trieste',
#  'Guinea',
#  'Dreznica',
#  'Portuguese Bend',
#  'Adyanpara',
#  'Cwmduad',
#  'Barsuwat',
#  'Jammu',
#  'California',
#  'Sabail',
#  'Sichuan',
#  'Idukki',
#  'Leh',
#  '',
#  'Manhattan',
#  'Trabuco Canyon',
#  'Malibu',
#  'Plomari',
#  'Parakkamala',
#  'Huai Sateng',
#  'Japan',
#  'Himachal Pradesh',
#  'Nihari',
#  'Kerala',
#  'Pothundi-Nelliampathy',
#  'Ishok Chingphu',
#  'Chitral',
#  '',
#  'Caddy Lake',
#  'Washington',
#  'Alsea',
#  'Kamakhya',
#  'Bhayangkara',
#  'Ucab',
#  'Quebec',
#  'California',
#  '',
#  'Guatemala',
#  'Luzon',
#  'Pagadian',
#  'Telford',
#  '',
#  'Nepal',
#  'Harlan',
#  'Kalinga province',
#  'Bhangagarh',
#  'Los Angeles',
#  'Rio de Janeiro',
#  'Alaverdi',
#  'Foshan',
#  'Bukit Panjuik',
#  '',
#  '',
#  '',
#  'Maasin',
#  'Piedmont',
#  'Thailand',
#  'Placerville',
#  'Covington',
#  'Veracruz',
#  'California',
#  'Semarang',
#  'Rishikesh-Gangotri',
#  '',
#  'Karja',
#  'Peru',
#  'Tengchong',
#  'Lece',
#  'Mt. Diwalwal',
#  'KY',
#  '',
#  'Batulawang',
#  'Tanauan',
#  'Salmon Creek',
#  'Bern',
#  'Apgar',
#  'Thistle',
#  'Sichuan',
#  'Lower Milford',
#  'Shumont',
#  'Santa Monica',
#  'Larga Circle',
#  'Ayyankunnu',
#  'Malibu',
#  'Sacramento',
#  '',
#  'Grouse Mountain',
#  'Tanintharyi',
#  'West Pokot',
#  'Guizhou',
#  '',
#  'Greece',
#  'Wuzhou',
#  'Falls Creek',
#  'Manali',
#  'Spiti Valley',
#  'Chagrin Falls',
#  'Pomendi',
#  'San Diego',
#  'Leh',
#  '',
#  'China',
#  '',
#  'Sifeng',
#  'Mirik',
#  'Petite Savanne',
#  'Butuan',
#  '',
#  'Smith River',
#  'Oregon',
#  'Sitio Bosquit',
#  'Dubrovnik',
#  'Sikkim',
#  'Mage',
#  'Betong',
#  '',
#  'Fort Carson',
#  'Nagercoil-Thiruvananthapuram',
#  'Ivel',
#  'Charlotteville',
#  'Simjung-9',
#  'Irosin',
#  'Lagonoy',
#  'Dhading',
#  'Ramona',
#  'Baguio city',
#  'Waterford',
#  'Mawbah',
#  '',
#  'Seattle',
#  'Amingaon',
#  '',
#  'Ranong',
#  'Sitio Naga',
#  'Bajpur',
#  'Guizhou',
#  'Pisco',
#  'Bradford',
#  '',
#  'Donetsk',
#  'Subang',
#  'Sainj',
#  'Peducha',
#  '',
#  'Sumner',
#  'Bhutan',
#  '',
#  'Japan',
#  'Bogor',
#  'Turnberry',
#  'Montecito',
#  'Riverdale',
#  'Mabian',
#  'Kaaawa',
#  'Vinton',
#  'Darjeeling',
#  'Romania',
#  'Dras',
#  'Indonesia',
#  'Junglewad',
#  'Uttarkashi',
#  'Lamjung',
#  'Gwynedd',
#  'Tobago',
#  'Buchanan County',
#  'Ruinibang',
#  'Karaj',
#  'Lenneng',
#  'Tambo',
#  'Kaihua',
#  'Yen Bai',
#  'Pourerere',
#  'Taplejung',
#  'Uttarakhand',
#  'Teknaf',
#  'Solan',
#  'Camillus',
#  'Iloilo',
#  'Zuma Beach',
#  'Solan',
#  'Utah',
#  'Karimganj',
#  'Raikot',
#  'Sailam village',
#  'Lyulin',
#  'Hezhang',
#  'Central Java',
#  'COLORADO SPRINGS',
#  'Raigad',
#  'Shanxi',
#  'Burien',
#  'Pyuthan',
#  'Jammu',
#  'Mount Vesuvius',
#  'Sedona',
#  'Jinzhong',
#  'Jamesville',
#  'Sangkanayu village',
#  'California',
#  'Barangay Limpapa',
#  'Laurel',
#  'Fremont',
#  'Warsaw',
#  'Petropolis',
#  'Estacada',
#  'Likely',
#  'Tupi',
#  'Imphal',
#  'Switzerland',
#  'Piarco',
#  '',
#  'Sandrathi village',
#  '',
#  'Mechi',
#  '',
#  'Ramban',
#  'Sidmouth',
#  '',
#  'Himachal Pradesh',
#  'Soreang',
#  'Myagdi',
#  'Bogor',
#  'Samanah',
#  'Ghawari',
#  'Tibet',
#  'Jalbire',
#  'Semarang',
#  'the Akto County',
#  'Guwahati',
#  'Glendora',
#  'Washington',
#  'Avgarch',
#  'Uttarkashi',
#  'Jammu',
#  '',
#  '',
#  'Canoe',
#  'Bangli',
#  'Seattle',
#  'Bali',
#  '',
#  'Bondurant',
#  'Sharote',
#  '',
#  'Barangay Sapangdako',
#  'Gatlinburg',
#  'Nedumangad',
#  'Ashe County',
#  'East Pittsburgh',
#  'Talkot Rural Municipality',
#  'Fall Creek',
#  'Tanjung',
#  'Limbe',
#  'Kabale',
#  'Nandi',
#  'Colorado',
#  '',
#  'Okanagan',
#  'Upazila',
#  'Austria',
#  'Malvern',
#  'Sonada',
#  'Chittagong',
#  'Bulathsinhala',
#  'Shoghi',
#  'Khanh Hoa',
#  'Bali',
#  'Uradale',
#  'Bunga',
#  'Williams Township',
#  'Rayagada',
#  'Masara',
#  'Maynonong',
#  'Yosemite Village',
#  'Gwent',
#  '',
#  'Odisha',
#  'Portland',
#  'Fujian province',
#  'Tasman',
#  'Keystone Canyon',
#  '',
#  'Mahakali',
#  'Yucca Ridge',
#  'Silverton',
#  'Vijayawada',
#  'Pantai Hillpark Phase',
#  'Chetwynd',
#  'Gudalur',
#  'Riviere Cyrique',
#  'Scotland',
#  '',
#  'Chitral',
#  'Wenatchee',
#  'Ucab',
#  'Ceheng',
#  'Khotang',
#  'Ghannin Dilbori',
#  'Uttarakhand',
#  'Chakki-Ka-Mor',
#  'Fiordland',
#  'Seri',
#  'Swan Lake',
#  'Rani-Ki-Bain',
#  'Upper Subansiri',
#  'Sitio Caduldulan',
#  'Wicklow',
#  'Tehran',
#  'OH',
#  'Lushan',
#  '',
#  '',
#  'Bali',
#  'Alabama',
#  'Marahau',
#  'Badrinath',
#  'Cebu',
#  'Princes Town',
#  'Muzaffarabad',
#  'Redwood Valley',
#  'Langholm',
#  'Oregon',
#  'Pacitan',
#  'Tomohon',
#  'Khizarabad',
#  'Seri',
#  'Ghatkopar',
#  'Thornhill',
#  'Washington',
#  'Towai',
#  'Shaoguan',
#  'Siena',
#  'Akhaldaba',
#  '',
#  'Quang Ninh',
#  'Traunsee',
#  'Pithoragarh',
#  'Beit Mery',
#  'Kampung Pangkalan Ampat',
#  'California',
#  'Nabunturan',
#  'Paradise',
#  'Libuganon',
#  'Pittsburgh',
#  'Calif',
#  'Deadman Creek',
#  'Shang',
#  'Remon',
#  'Macchil',
#  'Imphal',
#  'Oregon',
#  'Expressway-200',
#  'Mangaokewa',
#  'Quang Ngai',
#  'Rampur',
#  'Wye River',
#  'Siribagilu',
#  'Del Gallego',
#  'Kaneohe',
#  'Albay',
#  'Malki',
#  'Bukalasi',
#  'Norway',
#  'Bukalasi Sub-County',
#  'Mae Hong Son',
#  'Old Fort',
#  'Shongtong',
#  'Narrows',
#  'Danville',
#  'Hawaii',
#  'New Weligama',
#  'Chakla',
#  'California',
#  'Madikeri-Mangaluru',
#  'Plimmerton',
#  'Malibu',
#  'Sirivagilu',
#  'Springwood',
#  'Lake Elsinore',
#  'California',
#  'California',
#  'Kerala',
#  'Cauca',
#  'Apple Canyon',
#  'Moray',
#  'Kerala',
#  'Kallar',
#  '',
#  'Three Gorges Reservoir',
#  'Hardyston',
#  'Tottori',
#  'Jodupala',
#  '',
#  'Loch Ainort',
#  'Germany',
#  'Mangan',
#  'Tarbert',
#  'Kodagu',
#  'New Zealand',
#  '',
#  'San Ramon',
#  'Mexico City',
#  'Darwen',
#  'Yilan County',
#  'Mumbra',
#  'Kuala Enok',
#  'Unity Valley',
#  'Maui',
#  'Emery',
#  'Hastings',
#  'St Inez',
#  'Maughhanknockane',
#  '',
#  'Japan',
#  'Santa Cruz',
#  'Vanuatu',
#  'Gilman Springs',
#  'Tsuruga',
#  'Odisha',
#  'Apayao',
#  'Gold Bar',
#  'Duntroon',
#  'Kurseong',
#  'Alpine',
#  'Tangerang',
#  'Bazar',
#  'Costa Rica',
#  'Baguio',
#  '',
#  'Kuliang',
#  'San Martin',
#  'Thane',
#  'Sea Cliff',
#  'Binaliw',
#  'Erzurum',
#  'Tangkas village',
#  'Grantham',
#  'Mizoram',
#  'Milford',
#  'Central Java',
#  'Chomes',
#  'Nagar Valley',
#  'Ward Cove',
#  'Kigali',
#  'Sandy Bay',
#  'St. Paul',
#  'Goshen',
#  'Kaikoura',
#  'Hunan',
#  '',
#  'Veracruz',
#  'Llantrisant',
#  'Kayah',
#  'Vazhavara',
#  'Khongsang',
#  'Wye River',
#  'Ozarks',
#  'Tirupati',
#  'Fairmont',
#  '',
#  'Guerneville',
#  'Redding',
#  'Kyrgyzstan',
#  'Coonoor',
#  'Ventura',
#  'Vancouver',
#  'Peachland',
#  'Guizhou',
#  'Metlako Falls',
#  'Sunnybrae',
#  'Hattian Bala',
#  'Butwal',
#  '',
#  'Chesapeake Beach',
#  'Solihull',
#  'Uttarkashi',
#  '',
#  'Birkenhead',
#  '',
#  'Camarines Sur',
#  'Clinton',
#  'Vancouver',
#  'Palu',
#  'Talamudipi',
#  'Decker Canyon',
#  'Kamala',
#  'Yunnan',
#  'Hofu',
#  'Rangma',
#  'Bhojpur',
#  'Nagaland',
#  '',
#  'Kumta',
#  'Oaxaca',
#  'Himachal Pradesh',
#  'Pyuthan',
#  'Sichuan',
#  'Antiquity',
#  'Redwood City',
#  'Tamenglong',
#  '',
#  'Kodaikanal',
#  'Malibu',
#  'the Sandy River',
#  'Taclobo',
#  'Pakistan',
#  'Bulusan',
#  'Dharamshala',
#  'California',
#  'Alaska',
#  'Tagudin',
#  'Brgy',
#  'Kaslo',
#  '',
#  'Opunake Beach',
#  'Chenzhou',
#  'Qinghai',
#  '',
#  'Tulungagung',
#  'Dallas',
#  'Thalichi',
#  'Palawan',
#  'Wenshan',
#  'Thornburg',
#  'Yilan',
#  'Matrei',
#  'Jurassic Coast',
#  'Arshan',
#  'Ifugao',
#  'Watford City',
#  'Kenya',
#  'Bhavanagar',
#  'Massa',
#  "Xi'an",
#  'Košice Region',
#  'Rishkesh-Yamunotri',
#  'Hideaway Bay',
#  'Davesco-Soragno',
#  'Seattle',
#  'Atinggola',
#  'Burnley',
#  'Oakridge',
#  'Baltimore',
#  'Gulistan Colony',
#  'Soi Nanai',
#  'Sangrah',
#  'Malagutay',
#  'Shanxi province',
#  'Malshej',
#  'Bull Creek',
#  'Yunnan Province',
#  'Warasta',
#  '',
#  '',
#  'Yiyang',
#  'Limbang',
#  '',
#  'Kempty Falls',
#  'Mahur',
#  '',
#  'Coonoor',
#  'Chile',
#  'Brgy',
#  'Banihal',
#  'Cantonment',
#  'Osh',
#  '',
#  'Los Angeles',
#  'Alay',
#  'Penang',
#  'California',
#  'Addis Ababa',
#  'St Catherine',
#  'Chiweta',
#  'Chetwynd',
#  'Alpine',
#  'Badulla',
#  '',
#  'Kozhikode',
#  'Mizoram',
#  'Butwal',
#  'Uttarkashi',
#  'Bali',
#  'Hyderabad',
#  'Vals',
#  'Trail',
#  'Benthall',
#  '',
#  'Kerala',
#  'Mandi District',
#  'Valley',
#  'Covington',
#  'Malibu',
#  'California',
#  'Switzerland',
#  'Kerala',
#  'Gurupura',
#  'California',
#  'Maharashtra',
#  'Anhui Province',
#  '',
#  'Himachal Pradesh',
#  'Phrae',
#  'Yongshan County',
#  'Sichuan',
#  'Pembroke',
#  'Dharamsala-Kangra',
#  '',
#  'Gumaca',
#  'Healy',
#  '',
#  'Kohistan',
#  'Felida',
#  'American Fork Canyon',
#  'Letnitsa',
#  'Xinzhai',
#  'Edmonds',
#  'Chatham',
#  'Kampung Rangalau',
#  'Cache County',
#  '',
#  'Chittagong',
#  '',
#  'Kalimpong',
#  'Northwest Cornelius Pass',
#  'Hpakant',
#  'Clearlake Oaks',
#  'Rambi',
#  'Davao',
#  'Akhrori',
#  'Moore Town',
#  'Ainsworth Hot Springs',
#  'Fremont',
#  'Chongqing',
#  'Malidhor',
#  'Mabian',
#  '',
#  'San Isidro',
#  'Kashmir',
#  'Loufan County',
#  'Cebu City',
#  'Portland',
#  'Vasanta Way',
#  'Telemark',
#  'Corby',
#  'Jalal-Abad',
#  'Wellington',
#  'Yunnan',
#  'Sinam Khul',
#  'El Salvador',
#  'Ganja',
#  'La Crosse',
#  'Georgia',
#  'Nagaland',
#  'Uttarakhand',
#  'Numbay',
#  'Zurqui',
#  'Colorado',
#  'Masgad',
#  'Sangla Valley',
#  'Imphal',
#  'Xinjiang',
#  'Dakota County',
#  'Kwale',
#  'Calabria',
#  'Hunan',
#  'Chachagua de San Ramón',
#  'Kentucky',
#  'Artvin',
#  'Nueva Cinchona',
#  'Bengkayang',
#  'Roanoke',
#  'Baler',
#  'Diego Martin',
#  'Magelang',
#  'Kundasang',
#  'Tomohon',
#  'Jellico',
#  'Norway',
#  'Weymouth',
#  'Nevada City',
#  'West Virginia',
#  'Dendengan Dalam',
#  'Pandukeshwar',
#  'Wain-Erap',
#  'Okhareni',
#  'Arequipa',
#  'Washington',
#  'Combermere',
#  'Duarte',
#  'Kemble',
#  'Sicamous',
#  'Bhalukpong',
#  'Duarte',
#  'Escondido',
#  'Phearluang village',
#  'Churachandpur',
#  'Gayabari',
#  'Chittagong',
#  'Himachal Pradesh',
#  'Galeshwor',
#  'Jokatte',
#  'Palu',
#  'Asajaya',
#  '',
#  'Sri Lanka',
#  'Somerset',
#  '',
#  'Manila North',
#  'Fujian',
#  'West Virginia',
#  'Sarawak',
#  'Big Bar',
#  'Buff Bay Valley',
#  'Resheen',
#  '',
#  'San Dimas',
#  'Winifred',
#  'Imphal-Ukhrul',
#  'Manali',
#  'Lebak',
#  'Cape Town',
#  'Gaya',
#  'Clermont County',
#  'Houay Hip',
#  'Rio de Janeiro',
#  'Haldwani',
#  'Hixon Forest',
#  'Jalan Puncak Borneo',
#  '',
#  'Punggelan',
#  'Arizona',
#  'Kohima',
#  'Whidbey',
#  'Hetauda-Kulekhani',
#  'Tusom',
#  'San Cristobal',
#  'Coscomatepec',
#  'Nuwakot',
#  'Plumas County',
#  'Georgia',
#  '',
#  'Lower Tukau',
#  'Uttarakhand',
#  'Toowoomba',
#  'Sulawesi',
#  'Neryamangalam',
#  'Rio de Janeiro',
#  'Kalka-Shimla',
#  'Ogden',
#  'Scotts Valley',
#  'Western Highlands',
#  'Gilgit',
#  'Sichuan',
#  'Mizoram',
#  'Drabshalla',
#  'Lima',
#  'Pagosa Springs',
#  'Scotland',
#  'Crotone',
#  'Fangshan District',
#  'Whitehaven',
#  'Jomda County',
#  'Cayucos',
#  'Charleston',
#  'Fountain Valley',
#  '',
#  'Nelliyampathy',
#  'Idukki',
#  'Bern',
#  'Hollywood',
#  'Itogon',
#  'Pissouri',
#  '',
#  'Maryland',
#  'Vanuatu',
#  'Danville',
#  'Laem Thong',
#  'Guerrero',
#  'Ecuador',
#  'New Songjang village',
#  'Desamparados',
#  'Mission Bay',
#  'Sangihe island',
#  'East Cliff',
#  'Sebaste',
#  'Silang',
#  'Haast',
#  'Pakistan',
#  ...]

# %%
len(location_tags)
# Out:
# 3216

# %%
len(list(filter(None, location_tags)))
# Out:
# 2933

# %%
len(list(filter(None, date_tags)))
# Out:
# 1118

# %%
len(list(filter(None, time_tags)))
# Out:
# 367

# %%
len(list(filter(None, [date if date else time for date, time in zip(date_tags, time_tags)])))
# Out:
# 1332

# %%
print(len(time_tags))
print(len(date_tags))
print(len(location_tags))
# Out:
# 3216
# 3216
# 3216

# %%
landslide_data = {"version": "v1.0", "data": []}

for i, article_id in tqdm(enumerate(nasa_df["id"].to_numpy())):
    article_fields = {
        "id": int(article_id),
        "text": nasa_df.iloc[i]["text"],
        "published_date": nasa_df.iloc[i]["article_publish_date"],
        "event_date": nasa_df.iloc[i]["event_date"],
        "latitude": nasa_df.iloc[i]["latitude"],
        "longitude": nasa_df.iloc[i]["longitude"],
        "location_accuracy": nasa_df.iloc[i]["location_accuracy"],
        "url": nasa_df.iloc[i]["source_link"],
        "EVENT_CATEGORY": nasa_df.iloc[i]["landslide_category"],
        "EVENT_TRIGGER": nasa_df.iloc[i]["landslide_trigger"],
        "qas": {
            "LOC": location_tags[i],
            "TIME": time_tags[i],
            "DATE": date_tags[i],
            "CAS": cas_tags[i],
        },
    }
    landslide_data["data"].append(article_fields)
# Out:
# 3216it [00:03, 1061.27it/s]

# %%
with open(os.path.join(DATA_PATH, "landslide_data.json"), "w") as f:
    json.dump(landslide_data, f)
